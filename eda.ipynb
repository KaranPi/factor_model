# %%
import sys
from pathlib import Path

# Project root (one level ABOVE src)
PROJ_ROOT = Path(r"C:\Users\quantbase\Desktop\SyStrat_factmod")

if str(PROJ_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJ_ROOT))

print("Project root on sys.path:", PROJ_ROOT in map(Path, map(str, sys.path)))

from src.fm_config import DATA_INT
print("DATA_INT =", DATA_INT)
# Out:
# Project root on sys.path: True
# DATA_INT = C:\Users\quantbase\Desktop\SyStrat_factmod\data_int

# %%
import sys
from pathlib import Path

import numpy as np      # already in env — no new install
import pandas as pd     # already in env — no new install
import matplotlib.pyplot as plt  # already in env — no new install

# Project root and src import
PROJ_ROOT = Path(r"C:\Users\quantbase\Desktop\SyStrat_factmod")
if str(PROJ_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJ_ROOT))

from src.fm_config import DATA_INT   # no installation needed

pd.set_option("display.max_columns", None)

# %%
EDA_DIR = PROJ_ROOT / "reports" / "eda"
EDA_DIR.mkdir(parents=True, exist_ok=True)

# %%
# Factor returns (K factors × T dates)
fac_ret = pd.read_parquet(DATA_INT / "factor_returns_us.parquet")

# Residuals (N assets × T dates)
eps = pd.read_parquet(DATA_INT / "factor_residuals_us.parquet")

# Covariance matrix (K × K)
cov = pd.read_parquet(DATA_INT / "factor_cov_us.parquet")

fac_ret.head(), eps.head(), cov
# Out:
# (              market  sector_Communication Services  \
#  date
#  2021-11-02  0.001730                       0.001861
#  2021-11-03  0.004885                       0.006107
#  2021-11-04  0.007573                       0.001382
#  2021-11-05  0.005470                      -0.002796
#  2021-11-08  0.003165                      -0.005304
#
#              sector_Consumer Discretionary  sector_Consumer Staples  \
#  date
#  2021-11-02                      -0.006513                 0.003607
#  2021-11-03                       0.011467                 0.001578
#  2021-11-04                       0.009735                 0.000330
#  2021-11-05                      -0.004071                -0.004284
#  2021-11-08                      -0.011729                -0.013222
#
#              sector_Energy  sector_Financials  sector_Health Care  \
#  date
#  2021-11-02      -0.011131          -0.014072            0.005852
#  2021-11-03      -0.009858          -0.006224            0.002056
#  2021-11-04      -0.001522           0.002628           -0.003737
#  2021-11-05       0.004646           0.017368           -0.016948
#  2021-11-08       0.004207           0.007482            0.001224
#
#              sector_Industrials  sector_Information Technology  \
#  date
#  2021-11-02           -0.000519                       0.008403
#  2021-11-03           -0.004620                       0.001815
#  2021-11-04           -0.011362                       0.000710
#  2021-11-05            0.013672                      -0.003595
#  2021-11-08            0.001348                       0.002472
#
#              sector_Materials  EMA20_GAP       LIQ       MOM      QUAL  \
#  date
#  2021-11-02          0.012513   0.004956  0.001394  0.001188  0.004257
#  2021-11-03         -0.002321   0.003788  0.000185 -0.004937 -0.002133
#  2021-11-04          0.001836   0.006075  0.001545 -0.007080 -0.000148
#  2021-11-05         -0.003992   0.001548  0.002584 -0.001303 -0.001083
#  2021-11-08          0.013522   0.005164 -0.002133 -0.005546 -0.000277
#
#                  SIZE       VAL     VOL_Z
#  date
#  2021-11-02  0.000501 -0.002307 -0.006729
#  2021-11-03  0.002700  0.000287  0.002906
#  2021-11-04  0.001171 -0.001204  0.003309
#  2021-11-05  0.000277  0.005134 -0.001106
#  2021-11-08 -0.000367  0.003518  0.005161  ,
#  2021-11-02 -0.006897 -0.008097  0.012937 -0.010142 -0.001554
#  2021-11-03 -0.011607 -0.001380 -0.002739 -0.008496  0.006686
#  2021-11-04 -0.019582 -0.008887 -0.004371 -0.005298  0.010368
#  2021-11-05 -0.005239  0.007766  0.001889 -0.013787 -0.003583
#  2021-11-08 -0.005864  0.004542  0.007225  0.006297  0.007545  ,
#                                   market  sector_Communication Services  \
#  market                         0.026463                       0.008414
#  sector_Communication Services  0.008414                       0.017032
#  sector_Consumer Discretionary  0.008487                       0.008005
#  sector_Consumer Staples       -0.010900                      -0.006311
#  sector_Energy                 -0.006162                      -0.011110
#  sector_Financials              0.001840                      -0.001625
#  sector_Health Care            -0.008899                      -0.005409
#  sector_Industrials            -0.001306                      -0.005511
#  sector_Information Technology  0.009428                       0.009553
#  sector_Materials              -0.000903                      -0.004623
#  EMA20_GAP                     -0.000682                      -0.001286
#  LIQ                           -0.002970                      -0.001674
#  MOM                            0.001588                       0.000081
#  QUAL                          -0.000051                       0.000564
#  SIZE                           0.012927                       0.006940
#  VAL                            0.000020                      -0.000693
#  VOL_Z                          0.010845                       0.006388
#
#                                 sector_Consumer Discretionary  \
#  market                                              0.008487
#  sector_Communication Services                       0.008005
#  sector_Consumer Discretionary                       0.014943
#  sector_Consumer Staples                            -0.005282
#  sector_Energy                                      -0.009017
#  sector_Financials                                  -0.002296
#  sector_Health Care                                 -0.005830
#  sector_Industrials                                 -0.003897
#  sector_Information Technology                       0.008678
#  sector_Materials                                   -0.005303
#  EMA20_GAP                                          -0.000896
#  LIQ                                                -0.000335
#  MOM                                                -0.000393
#  QUAL                                               -0.000558
#  SIZE                                                0.005760
#  VAL                                                -0.000930
#  VOL_Z                                               0.006528
#
#                                 sector_Consumer Staples  sector_Energy  \
#  market                                       -0.010900      -0.006162
#  sector_Communication Services                -0.006311      -0.011110
#  sector_Consumer Discretionary                -0.005282      -0.009017
#  sector_Consumer Staples                       0.013803       0.000168
#  sector_Energy                                 0.000168       0.028973
#  sector_Financials                            -0.001979      -0.003319
#  sector_Health Care                            0.007202       0.000771
#  sector_Industrials                           -0.001327       0.005847
#  sector_Information Technology                -0.007071      -0.010244
#  sector_Materials                              0.000797      -0.002069
#  EMA20_GAP                                     0.000286       0.001148
#  LIQ                                           0.001683       0.001510
#  MOM                                          -0.001047       0.001161
#  QUAL                                         -0.000172      -0.000726
#  SIZE                                         -0.006198      -0.005122
#  VAL                                          -0.000764       0.004336
#  VOL_Z                                        -0.007791      -0.002868
#
#                                 sector_Financials  sector_Health Care  \
#  market                                  0.001840           -0.008899
#  sector_Communication Services          -0.001625           -0.005409
#  sector_Consumer Discretionary          -0.002296           -0.005830
#  sector_Consumer Staples                -0.001979            0.007202
#  sector_Energy                          -0.003319            0.000771
#  sector_Financials                       0.013833           -0.001156
#  sector_Health Care                     -0.001156            0.010429
#  sector_Industrials                     -0.001067           -0.000976
#  sector_Information Technology          -0.001986           -0.005953
#  sector_Materials                       -0.000404            0.000922
#  EMA20_GAP                               0.000544            0.000513
#  LIQ                                    -0.000837            0.000282
#  MOM                                    -0.000710           -0.000328
#  QUAL                                    0.000314            0.000627
#  SIZE                                    0.000697           -0.004763
#  VAL                                    -0.001165           -0.000888
#  VOL_Z                                   0.000178           -0.005522
#
#                                 sector_Industrials  \
#  market                                  -0.001306
#  sector_Communication Services           -0.005511
#  sector_Consumer Discretionary           -0.003897
#  sector_Consumer Staples                 -0.001327
#  sector_Energy                            0.005847
#  sector_Financials                       -0.001067
#  sector_Health Care                      -0.000976
#  sector_Industrials                       0.011735
#  sector_Information Technology           -0.003902
#  sector_Materials                        -0.000902
#  EMA20_GAP                                0.000131
#  LIQ                                      0.000276
#  MOM                                      0.000610
#  QUAL                                    -0.000670
#  SIZE                                    -0.002246
#  VAL                                      0.001381
#  VOL_Z                                   -0.001545
#
#                                 sector_Information Technology  \
#  market                                              0.009428
#  sector_Communication Services                       0.009553
#  sector_Consumer Discretionary                       0.008678
#  sector_Consumer Staples                            -0.007071
#  sector_Energy                                      -0.010244
#  sector_Financials                                  -0.001986
#  sector_Health Care                                 -0.005953
#  sector_Industrials                                 -0.003902
#  sector_Information Technology                       0.014976
#  sector_Materials                                   -0.004050
#  EMA20_GAP                                          -0.000444
#  LIQ                                                -0.000302
#  MOM                                                 0.001067
#  QUAL                                                0.000245
#  SIZE                                                0.006387
#  VAL                                                -0.001150
#  VOL_Z                                               0.006636
#
#                                 sector_Materials  EMA20_GAP       LIQ  \
#  market                                -0.000903  -0.000682 -0.002970
#  sector_Communication Services         -0.004623  -0.001286 -0.001674
#  sector_Consumer Discretionary         -0.005303  -0.000896 -0.000335
#  sector_Consumer Staples                0.000797   0.000286  0.001683
#  sector_Energy                         -0.002069   0.001148  0.001510
#  sector_Financials                     -0.000404   0.000544 -0.000837
#  sector_Health Care                     0.000922   0.000513  0.000282
#  sector_Industrials                    -0.000902   0.000131  0.000276
#  sector_Information Technology         -0.004050  -0.000444 -0.000302
#  sector_Materials                       0.015633   0.000004 -0.000602
#  EMA20_GAP                              0.000004   0.004668  0.000031
#  LIQ                                   -0.000602   0.000031  0.002058
#  MOM                                   -0.000442  -0.000221 -0.000093
#  QUAL                                   0.000376  -0.000132 -0.000193
#  SIZE                                  -0.001455  -0.000433 -0.002209
#  VAL                                   -0.000127   0.000125 -0.000112
#  VOL_Z                                 -0.002004  -0.000683 -0.001557
#
#                                      MOM      QUAL      SIZE       VAL  \
#  market                         0.001588 -0.000051  0.012927  0.000020
#  sector_Communication Services  0.000081  0.000564  0.006940 -0.000693
#  sector_Consumer Discretionary -0.000393 -0.000558  0.005760 -0.000930
#  sector_Consumer Staples       -0.001047 -0.000172 -0.006198 -0.000764
#  sector_Energy                  0.001161 -0.000726 -0.005122  0.004336
#  sector_Financials             -0.000710  0.000314  0.000697 -0.001165
#  sector_Health Care            -0.000328  0.000627 -0.004763 -0.000888
#  sector_Industrials             0.000610 -0.000670 -0.002246  0.001381
#  sector_Information Technology  0.001067  0.000245  0.006387 -0.001150
#  sector_Materials              -0.000442  0.000376 -0.001455 -0.000127
#  EMA20_GAP                     -0.000221 -0.000132 -0.000433  0.000125
#  LIQ                           -0.000093 -0.000193 -0.002209 -0.000112
#  MOM                            0.002648 -0.000087  0.000481  0.000100
#  QUAL                          -0.000087  0.000965  0.000052 -0.000534
#  SIZE                           0.000481  0.000052  0.007841 -0.000082
#  VAL                            0.000100 -0.000534 -0.000082  0.001841
#  VOL_Z                          0.000503 -0.000067  0.006198 -0.000117
#
#                                    VOL_Z
#  market                         0.010845
#  sector_Communication Services  0.006388
#  sector_Consumer Discretionary  0.006528
#  sector_Consumer Staples       -0.007791
#  sector_Energy                 -0.002868
#  sector_Financials              0.000178
#  sector_Health Care            -0.005522
#  sector_Industrials            -0.001545
#  sector_Information Technology  0.006636
#  sector_Materials              -0.002004
#  EMA20_GAP                     -0.000683
#  LIQ                           -0.001557
#  MOM                            0.000503
#  QUAL                          -0.000067
#  SIZE                           0.006198
#  VAL                           -0.000117
#  VOL_Z                          0.009204  )

# %%
#------BASIC STATS/factor

# %%
# Assume these are daily factor returns; adjust if you changed frequency
trading_days = 252

mu = fac_ret.mean()
sigma = fac_ret.std()
sharpe = (mu * trading_days) / (sigma * np.sqrt(trading_days))

summary = pd.DataFrame({
    "mean_daily": mu,
    "vol_daily": sigma,
    "ann_mean": mu * trading_days,
    "ann_vol": sigma * np.sqrt(trading_days),
    "ann_sharpe": sharpe,
})

summary
# Out:
#                                mean_daily  vol_daily  ann_mean   ann_vol  \
# market                           0.000631   0.010248  0.158890  0.162676
# sector_Communication Services    0.000082   0.008221  0.020770  0.130505
# sector_Consumer Discretionary   -0.000341   0.007701 -0.085975  0.122243
# sector_Consumer Staples         -0.000055   0.007401 -0.013933  0.117488
# sector_Energy                    0.000220   0.010722  0.055372  0.170214
# sector_Financials               -0.000049   0.007409 -0.012282  0.117612
# sector_Health Care              -0.000133   0.006433 -0.033575  0.102125
# sector_Industrials               0.000241   0.006824  0.060667  0.108330
# sector_Information Technology   -0.000004   0.007709 -0.000957  0.122377
# sector_Materials                 0.000039   0.007876  0.009914  0.125032
# EMA20_GAP                        0.004262   0.004304  1.073976  0.068326
# LIQ                             -0.000120   0.002858 -0.030222  0.045368
# MOM                             -0.000041   0.003242 -0.010295  0.051457
# QUAL                            -0.000007   0.001957 -0.001845  0.031061
# SIZE                             0.000213   0.005578  0.053659  0.088548
# VAL                              0.000145   0.002703  0.036552  0.042912
# VOL_Z                            0.000053   0.006043  0.013351  0.095935
#
#                                ann_sharpe
# market                           0.976730
# sector_Communication Services    0.159154
# sector_Consumer Discretionary   -0.703314
# sector_Consumer Staples         -0.118589
# sector_Energy                    0.325306
# sector_Financials               -0.104432
# sector_Health Care              -0.328769
# sector_Industrials               0.560021
# sector_Information Technology   -0.007820
# sector_Materials                 0.079288
# EMA20_GAP                       15.718468
# LIQ                             -0.666146
# MOM                             -0.200067
# QUAL                            -0.059386
# SIZE                             0.605985
# VAL                              0.851785
# VOL_Z                            0.139167

# %%
summary.sort_values("ann_sharpe", ascending=False)
# Out:
#                                mean_daily  vol_daily  ann_mean   ann_vol  \
# EMA20_GAP                        0.004262   0.004304  1.073976  0.068326
# market                           0.000631   0.010248  0.158890  0.162676
# VAL                              0.000145   0.002703  0.036552  0.042912
# SIZE                             0.000213   0.005578  0.053659  0.088548
# sector_Industrials               0.000241   0.006824  0.060667  0.108330
# sector_Energy                    0.000220   0.010722  0.055372  0.170214
# sector_Communication Services    0.000082   0.008221  0.020770  0.130505
# VOL_Z                            0.000053   0.006043  0.013351  0.095935
# sector_Materials                 0.000039   0.007876  0.009914  0.125032
# sector_Information Technology   -0.000004   0.007709 -0.000957  0.122377
# QUAL                            -0.000007   0.001957 -0.001845  0.031061
# sector_Financials               -0.000049   0.007409 -0.012282  0.117612
# sector_Consumer Staples         -0.000055   0.007401 -0.013933  0.117488
# MOM                             -0.000041   0.003242 -0.010295  0.051457
# sector_Health Care              -0.000133   0.006433 -0.033575  0.102125
# LIQ                             -0.000120   0.002858 -0.030222  0.045368
# sector_Consumer Discretionary   -0.000341   0.007701 -0.085975  0.122243
#
#                                ann_sharpe
# EMA20_GAP                       15.718468
# market                           0.976730
# VAL                              0.851785
# SIZE                             0.605985
# sector_Industrials               0.560021
# sector_Energy                    0.325306
# sector_Communication Services    0.159154
# VOL_Z                            0.139167
# sector_Materials                 0.079288
# sector_Information Technology   -0.007820
# QUAL                            -0.059386
# sector_Financials               -0.104432
# sector_Consumer Staples         -0.118589
# MOM                             -0.200067
# sector_Health Care              -0.328769
# LIQ                             -0.666146
# sector_Consumer Discretionary   -0.703314

# %%
#-------Time series plot----------

# %%
fig, ax = plt.subplots(figsize=(10, 5))

fac_ret[["market", "VAL", "SIZE", "MOM"]].cumsum().plot(ax=ax)
ax.set_title("Cumulative factor returns (US)")
ax.set_xlabel("Date")
ax.set_ylabel("Cumulative return")
plt.tight_layout()
plt.show()

# %%
fac_ret.loc["2024-01-01":"2025-01-31", ["market", "VAL", "SIZE", "MOM"]].cumsum().plot(figsize=(10, 5))
plt.title("Cumulative factor returns")
plt.xlabel("Date")
plt.ylabel("Cumulative return")
plt.tight_layout()
plt.show()

# %%
#---------Hisgtograms/factor

# %%
fac_ret[["market", "VAL", "SIZE", "MOM"]].hist(bins=90, figsize=(10, 8))
plt.suptitle("Factor return distributions (daily)", y=1.02)
plt.tight_layout()
plt.show()

# %%
dist_stats = pd.DataFrame({
    "skew": fac_ret.skew(),
    "kurtosis_excess": fac_ret.kurtosis(),  # excess kurtosis
})
dist_stats
# Out:
#                                    skew  kurtosis_excess
# market                        -0.174895         2.182543
# sector_Communication Services -0.026626         1.565841
# sector_Consumer Discretionary  0.010215         0.689541
# sector_Consumer Staples        0.190403         1.608134
# sector_Energy                  0.077965        -0.188315
# sector_Financials             -0.061707         0.617262
# sector_Health Care             0.270517         0.875201
# sector_Industrials            -0.297696         0.820411
# sector_Information Technology -0.035140         1.168954
# sector_Materials              -0.028942         0.637198
# EMA20_GAP                      1.582593         8.349805
# LIQ                           -0.098824         0.904257
# MOM                           -0.126607         1.569175
# QUAL                           0.083491         0.516760
# SIZE                           0.012739         1.698280
# VAL                            0.085440         0.277848
# VOL_Z                          0.322934         2.314570

# %%
#-----Covariance

# %%
# Correlation matrix from factor returns
corr = fac_ret.corr()

corr
# Out:
#                                  market  sector_Communication Services  \
# market                         1.000000                       0.396326
# sector_Communication Services  0.396326                       1.000000
# sector_Consumer Discretionary  0.426796                       0.501758
# sector_Consumer Staples       -0.570304                      -0.411614
# sector_Energy                 -0.222521                      -0.500127
# sector_Financials              0.096168                      -0.105897
# sector_Health Care            -0.535671                      -0.405876
# sector_Industrials            -0.074105                      -0.389785
# sector_Information Technology  0.473588                       0.598140
# sector_Materials              -0.044380                      -0.283298
# EMA20_GAP                     -0.061380                      -0.144166
# LIQ                           -0.402461                      -0.282717
# MOM                            0.189726                       0.012007
# QUAL                          -0.010147                       0.139197
# SIZE                           0.897426                       0.600574
# VAL                            0.002927                      -0.123702
# VOL_Z                          0.694922                       0.510183
#
#                                sector_Consumer Discretionary  \
# market                                              0.426796
# sector_Communication Services                       0.501758
# sector_Consumer Discretionary                       1.000000
# sector_Consumer Staples                            -0.367801
# sector_Energy                                      -0.433358
# sector_Financials                                  -0.159720
# sector_Health Care                                 -0.467021
# sector_Industrials                                 -0.294274
# sector_Information Technology                       0.580122
# sector_Materials                                   -0.346985
# EMA20_GAP                                          -0.107273
# LIQ                                                -0.060437
# MOM                                                -0.062406
# QUAL                                               -0.146995
# SIZE                                                0.532100
# VAL                                                -0.177363
# VOL_Z                                               0.556672
#
#                                sector_Consumer Staples  sector_Energy  \
# market                                       -0.570304      -0.222521
# sector_Communication Services                -0.411614      -0.500127
# sector_Consumer Discretionary                -0.367801      -0.433358
# sector_Consumer Staples                       1.000000       0.008407
# sector_Energy                                 0.008407       1.000000
# sector_Financials                            -0.143185      -0.165805
# sector_Health Care                            0.600209       0.044382
# sector_Industrials                           -0.104273       0.317073
# sector_Information Technology                -0.491805      -0.491788
# sector_Materials                              0.054271      -0.097214
# EMA20_GAP                                     0.035622       0.098706
# LIQ                                           0.315727       0.195490
# MOM                                          -0.173155       0.132595
# QUAL                                         -0.047079      -0.137272
# SIZE                                         -0.595818      -0.339841
# VAL                                          -0.151581       0.593575
# VOL_Z                                        -0.691265      -0.175622
#
#                                sector_Financials  sector_Health Care  \
# market                                  0.096168           -0.535671
# sector_Communication Services          -0.105897           -0.405876
# sector_Consumer Discretionary          -0.159720           -0.467021
# sector_Consumer Staples                -0.143185            0.600209
# sector_Energy                          -0.165805            0.044382
# sector_Financials                       1.000000           -0.096234
# sector_Health Care                     -0.096234            1.000000
# sector_Industrials                     -0.083739           -0.088179
# sector_Information Technology          -0.138007           -0.476325
# sector_Materials                       -0.027471            0.072177
# EMA20_GAP                               0.067708            0.073481
# LIQ                                    -0.156814            0.060840
# MOM                                    -0.117272           -0.062443
# QUAL                                    0.085864            0.197697
# SIZE                                    0.066967           -0.526673
# VAL                                    -0.230883           -0.202546
# VOL_Z                                   0.015798           -0.563583
#
#                                sector_Industrials  \
# market                                  -0.074105
# sector_Communication Services           -0.389785
# sector_Consumer Discretionary           -0.294274
# sector_Consumer Staples                 -0.104273
# sector_Energy                            0.317073
# sector_Financials                       -0.083739
# sector_Health Care                      -0.088179
# sector_Industrials                       1.000000
# sector_Information Technology           -0.294362
# sector_Materials                        -0.066629
# EMA20_GAP                                0.017643
# LIQ                                      0.056162
# MOM                                      0.109461
# QUAL                                    -0.199167
# SIZE                                    -0.234118
# VAL                                      0.297107
# VOL_Z                                   -0.148664
#
#                                sector_Information Technology  \
# market                                              0.473588
# sector_Communication Services                       0.598140
# sector_Consumer Discretionary                       0.580122
# sector_Consumer Staples                            -0.491805
# sector_Energy                                      -0.491788
# sector_Financials                                  -0.138007
# sector_Health Care                                 -0.476325
# sector_Industrials                                 -0.294362
# sector_Information Technology                       1.000000
# sector_Materials                                   -0.264718
# EMA20_GAP                                          -0.053091
# LIQ                                                -0.054440
# MOM                                                 0.169507
# QUAL                                                0.064523
# SIZE                                                0.589417
# VAL                                                -0.218986
# VOL_Z                                               0.565212
#
#                                sector_Materials  EMA20_GAP       LIQ  \
# market                                -0.044380  -0.061380 -0.402461
# sector_Communication Services         -0.283298  -0.144166 -0.282717
# sector_Consumer Discretionary         -0.346985  -0.107273 -0.060437
# sector_Consumer Staples                0.054271   0.035622  0.315727
# sector_Energy                         -0.097214   0.098706  0.195490
# sector_Financials                     -0.027471   0.067708 -0.156814
# sector_Health Care                     0.072177   0.073481  0.060840
# sector_Industrials                    -0.066629   0.017643  0.056162
# sector_Information Technology         -0.264718  -0.053091 -0.054440
# sector_Materials                       1.000000   0.000478 -0.106187
# EMA20_GAP                              0.000478   1.000000  0.009913
# LIQ                                   -0.106187   0.009913  1.000000
# MOM                                   -0.068753  -0.062984 -0.040034
# QUAL                                   0.096705  -0.061988 -0.136741
# SIZE                                  -0.131447  -0.071588 -0.549771
# VAL                                   -0.023578   0.042493 -0.057461
# VOL_Z                                 -0.167065  -0.104224 -0.357632
#
#                                     MOM      QUAL      SIZE       VAL  \
# market                         0.189726 -0.010147  0.897426  0.002927
# sector_Communication Services  0.012007  0.139197  0.600574 -0.123702
# sector_Consumer Discretionary -0.062406 -0.146995  0.532100 -0.177363
# sector_Consumer Staples       -0.173155 -0.047079 -0.595818 -0.151581
# sector_Energy                  0.132595 -0.137272 -0.339841  0.593575
# sector_Financials             -0.117272  0.085864  0.066967 -0.230883
# sector_Health Care            -0.062443  0.197697 -0.526673 -0.202546
# sector_Industrials             0.109461 -0.199167 -0.234118  0.297107
# sector_Information Technology  0.169507  0.064523  0.589417 -0.218986
# sector_Materials              -0.068753  0.096705 -0.131447 -0.023578
# EMA20_GAP                     -0.062984 -0.061988 -0.071588  0.042493
# LIQ                           -0.040034 -0.136741 -0.549771 -0.057461
# MOM                            1.000000 -0.054734  0.105616  0.045116
# QUAL                          -0.054734  1.000000  0.018834 -0.400974
# SIZE                           0.105616  0.018834  1.000000 -0.021574
# VAL                            0.045116 -0.400974 -0.021574  1.000000
# VOL_Z                          0.101802 -0.022363  0.729612 -0.028320
#
#                                   VOL_Z
# market                         0.694922
# sector_Communication Services  0.510183
# sector_Consumer Discretionary  0.556672
# sector_Consumer Staples       -0.691265
# sector_Energy                 -0.175622
# sector_Financials              0.015798
# sector_Health Care            -0.563583
# sector_Industrials            -0.148664
# sector_Information Technology  0.565212
# sector_Materials              -0.167065
# EMA20_GAP                     -0.104224
# LIQ                           -0.357632
# MOM                            0.101802
# QUAL                          -0.022363
# SIZE                           0.729612
# VAL                           -0.028320
# VOL_Z                          1.000000

# %%
def plot_matrix(mat: pd.DataFrame, title: str):
    fig, ax = plt.subplots(figsize=(10, 10))
    im = ax.imshow(mat.values)
    ax.set_xticks(range(len(mat.columns)))
    ax.set_yticks(range(len(mat.index)))
    ax.set_xticklabels(mat.columns, rotation=90, ha="right")
    ax.set_yticklabels(mat.index)
    ax.set_title(title)
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
    plt.tight_layout()
    plt.show()

plot_matrix(corr, "Factor correlation matrix (US)")
plot_matrix(cov, "Factor covariance matrix (annualised, US)")

# %%
#-----eigen values---------
eigvals, eigvecs = np.linalg.eigh(cov.values)
eigvals_sorted = np.sort(eigvals)[::-1]
eigvals_sorted
# Out:
# array([ 7.69186834e-02,  3.21785103e-02,  2.08899892e-02,  1.47524648e-02,
#         1.07567327e-02,  9.84617575e-03,  8.05198906e-03,  6.31700833e-03,
#         4.92578683e-03,  4.45961549e-03,  2.47554058e-03,  2.05127049e-03,
#         1.58224314e-03,  1.05799447e-03,  4.62949611e-04,  3.19289674e-04,
#        -4.97322815e-18])

# %%
#-----Residuals----

# Residuals should be roughly mean-zero and low-vol relative to total returns.

# %%
eps.describe()
# Out:
#              AAPL        ABBV         ABT        AMAT         AMD        AMZN  \
# count  769.000000  769.000000  769.000000  769.000000  769.000000  769.000000
# mean    -0.000723    0.000340    0.000226    0.000350    0.000370   -0.000107
# std      0.014606    0.007931    0.009410    0.009724    0.010014    0.011454
# min     -0.066325   -0.025281   -0.028201   -0.029194   -0.039911   -0.039210
# 25%     -0.009727   -0.004755   -0.005293   -0.006402   -0.005559   -0.007085
# 50%     -0.000633    0.000179   -0.000014    0.000092    0.000105   -0.000109
# 75%      0.007719    0.005625    0.005872    0.006700    0.006475    0.006941
# max      0.050208    0.031796    0.036504    0.052220    0.050947    0.043425
#
#              AVGO         CAT        COST         CRM        CSCO         CVX  \
# count  769.000000  769.000000  769.000000  769.000000  769.000000  769.000000
# mean    -0.000705   -0.000256   -0.000012    0.000389   -0.000083   -0.000535
# std      0.008812    0.009374    0.008895    0.010550    0.008429    0.010002
# min     -0.029343   -0.031467   -0.032882   -0.038776   -0.031477   -0.036813
# 25%     -0.006214   -0.006148   -0.005612   -0.006457   -0.005544   -0.007521
# 50%     -0.000673   -0.000209   -0.000137    0.000300   -0.000358   -0.000383
# 75%      0.004641    0.005486    0.005483    0.006882    0.005182    0.006586
# max      0.036650    0.034421    0.038326    0.048543    0.035751    0.039920
#
#                GE        GOOG          HD         IBM        ISRG         JNJ  \
# count  769.000000  769.000000  769.000000  769.000000  769.000000  769.000000
# mean    -0.000420   -0.000175    0.000599   -0.000154    0.000224   -0.000184
# std      0.011323    0.012328    0.009691    0.008520    0.013391    0.006729
# min     -0.044610   -0.057839   -0.036473   -0.038359   -0.053035   -0.022034
# 25%     -0.006223   -0.007853   -0.005322   -0.005701   -0.007578   -0.004405
# 50%     -0.000407   -0.000569    0.000530    0.000105    0.000289   -0.000061
# 75%      0.006111    0.006812    0.006932    0.005071    0.007645    0.003982
# max      0.041729    0.058532    0.034324    0.035333    0.054026    0.025784
#
#                KO         LIN         LLY          MA         MCD        META  \
# count  769.000000  769.000000  769.000000  769.000000  769.000000  769.000000
# mean     0.000067   -0.000016   -0.000415   -0.000177    0.000209   -0.000528
# std      0.007972    0.006234    0.007834    0.006183    0.009023    0.012347
# min     -0.028446   -0.024805   -0.029703   -0.032296   -0.032723   -0.056351
# 25%     -0.004487   -0.003348   -0.005378   -0.003931   -0.005547   -0.007898
# 50%      0.000243   -0.000143   -0.000426    0.000177    0.000501   -0.000635
# 75%      0.004639    0.003166    0.004588    0.003525    0.005664    0.007073
# max      0.037559    0.025947    0.025267    0.021550    0.029674    0.044009
#
#               MRK        MSFT          MU        NFLX        NVDA        ORCL  \
# count  769.000000  769.000000  769.000000  769.000000  769.000000  769.000000
# mean     0.000344   -0.000341    0.000400   -0.000441   -0.000837   -0.000341
# std      0.007599    0.013836    0.011394    0.011400    0.012008    0.010429
# min     -0.032342   -0.073556   -0.036073   -0.038779   -0.047391   -0.054343
# 25%     -0.004402   -0.008026   -0.007075   -0.007060   -0.008048   -0.006270
# 50%      0.000410   -0.000533    0.000501   -0.000742   -0.001279    0.000084
# 75%      0.004795    0.007050    0.007069    0.005633    0.005695    0.005935
# max      0.032687    0.053525    0.049008    0.046216    0.041510    0.038906
#
#               PEP          PG        PLTR         RTX         TMO        TMUS  \
# count  769.000000  769.000000  769.000000  769.000000  769.000000  769.000000
# mean     0.000101    0.000083    0.000229   -0.000198    0.000071   -0.000306
# std      0.007443    0.006161    0.015556    0.009409    0.010134    0.010220
# min     -0.026810   -0.028634   -0.048314   -0.031528   -0.034204   -0.039932
# 25%     -0.004442   -0.003855   -0.009491   -0.006002   -0.005754   -0.006847
# 50%      0.000343    0.000072    0.001105   -0.000197   -0.000121   -0.000266
# 75%      0.004743    0.003946    0.010118    0.005036    0.006184    0.005894
# max      0.027808    0.019965    0.059948    0.038981    0.044857    0.038611
#
#              TSLA         UNH           V         WMT         XOM
# count  769.000000  769.000000  769.000000  769.000000  769.000000
# mean     0.000525   -0.000122   -0.000136   -0.000302   -0.000838
# std      0.013786    0.007543    0.005796    0.006935    0.009699
# min     -0.059331   -0.025512   -0.024608   -0.030581   -0.038069
# 25%     -0.007858   -0.005151   -0.003300   -0.004273   -0.006757
# 50%      0.000340   -0.000329   -0.000188   -0.000355   -0.000366
# 75%      0.008789    0.004630    0.003067    0.003729    0.005519
# max      0.053460    0.032912    0.023777    0.043099    0.028687

# %%
fig, ax = plt.subplots(figsize=(10, 5))
eps.cumsum().plot(ax=ax)
ax.set_title("Cumulative residual returns (US assets)")
ax.set_xlabel("Date")
ax.set_ylabel("Cumulative residual")
#plt.tight_layout()
plt.show()
fig.savefig(EDA_DIR / "cum_residual_rets.png", dpi=150, bbox_inches="tight")

# %%
# Check residual correlation; ideally low:

eps_corr = eps.corr()
eps_corr
# Out:
#           AAPL      ABBV       ABT      AMAT       AMD      AMZN      AVGO  \
# AAPL  1.000000 -0.171643 -0.580878 -0.192827  0.138029  0.701016  0.334547
    decompose_portfolio_us,
    sanity_check_decomposition_us,
)
from src.fm_factor_panel import build_us_factor_panel

# Load factor panel (ret + exposures)
factor_panel = pd.read_parquet(DATA_INT / "factor_panel_us.parquet")

# Build equal-weight portfolio over all available assets
tickers_model = list(eps.columns)
dates_model = fac_ret.index

weights_eq = build_equal_weight_portfolio(
    tickers=tickers_model,
    dates=dates_model,
)

factor_contrib, resid_contrib, total_from_model = decompose_portfolio_us(
    weights=weights_eq,
    factor_panel=factor_panel,
    factor_returns=fac_ret,
    residuals=eps,
)

true_ret, model_ret, diff, rmse, max_abs_diff = sanity_check_decomposition_us(
    weights=weights_eq,
    factor_panel=factor_panel,
    total_from_model=total_from_model,
)

rmse, max_abs_diff
# Out:
# (0.0014236578066900685, 0.00828486386478378)

# %%
fig, ax = plt.subplots(figsize=(10, 5))
true_ret.cumsum().plot(ax=ax, label="True portfolio")
model_ret.cumsum().plot(ax=ax, linestyle="--", label="Factor model")
ax.legend()
ax.set_title("Portfolio cumulative return: true vs factor model")
ax.set_xlabel("Date")
ax.set_ylabel("Cumulative return")
plt.tight_layout()
plt.show()
fig.savefig(EDA_DIR / "factor_cumret_us.png", dpi=150, bbox_inches="tight")

# %%
factor_contrib.cumsum().plot(figsize=(10, 5))
plt.title("Cumulative factor contributions (equal-weight US portfolio)")
plt.xlabel("Date")
plt.ylabel("Contribution to return")
plt.tight_layout()
plt.show()
fig.savefig(EDA_DIR / "cum_factor_contrib.png", dpi=150, bbox_inches="tight")

resid_contrib.cumsum().plot(figsize=(10, 5))
plt.title("Cumulative residual contributions (equal-weight US portfolio)")
plt.xlabel("Date")
plt.ylabel("Contribution to return")

plt.tight_layout()
plt.show()

fig.savefig(EDA_DIR / "cum_resid_contrib.png", dpi=150, bbox_inches="tight")

# %%
#------Per-factor “risk budget”----------

# useful to see if market absolutely dominates risk.

# %%
# Example: equally exposed across factors (just as a toy)
K = cov.shape[0]
w_f = np.ones(K) / np.sqrt(K)  # normalised for convenience

# Factor variance contribution per factor (diagonal of w_i w_j Sigma_ij)
var_total = float(w_f.T @ cov.values @ w_f)
marginal = cov.values @ w_f
component = w_f * marginal
var_contrib = pd.Series(component / var_total, index=cov.index)

var_total, var_contrib
# Out:
# (0.005940036033632338,
#  market                           0.476731
#  sector_Communication Services    0.185526
#  sector_Consumer Discretionary    0.174914
#  sector_Consumer Staples         -0.246619
#  sector_Energy                   -0.066574
#  sector_Financials                0.008533
#  sector_Health Care              -0.187933
#  sector_Industrials              -0.033362
#  sector_Information Technology    0.216550
#  sector_Materials                -0.051034
#  EMA20_GAP                        0.026463
#  LIQ                             -0.049954
#  MOM                              0.048693
#  QUAL                            -0.000470
#  SIZE                             0.245346
#  VAL                              0.012291
#  VOL_Z                            0.240901
#  dtype: float64)

# %%
#------Saving Outputs-------

# %%
summary.to_csv(EDA_DIR / "factor_summary_us.csv", index=True)
corr.to_csv(EDA_DIR / "factor_corr_us.csv", index=True)
cov.to_csv(EDA_DIR / "factor_cov_us.csv", index=True)
eps_corr.to_csv(EDA_DIR / "residual_corr_us.csv", index=True)
