# %%
import sys
from pathlib import Path

# Project root (one level ABOVE src)
PROJ_ROOT = Path(r"C:\Users\quantbase\Desktop\SyStrat_factmod")

if str(PROJ_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJ_ROOT))

print("Project root on sys.path:", PROJ_ROOT in map(Path, map(str, sys.path)))

from src.fm_config import DATA_INT
print("DATA_INT =", DATA_INT)
# Out:
# Project root on sys.path: True
# DATA_INT = C:\Users\quantbase\Desktop\SyStrat_factmod\data_int

# %%
from datetime import date
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from src.fm_config import DATA_INT
from src.fm_data_prices import load_us_prices, load_nse_prices
from src.fm_fundamentals import (
    load_us_income_ttm,
    load_us_balance_ttm,
    load_us_cashflow_ttm,
)
from src.fm_returns import build_returns_all, build_mkt_cap_all
from src.fm_panel_us import build_us_panel
from src.fm_factors import (
    build_us_tier1_factors,
    build_us_tier2_factors,
    build_us_tier3_factors,
    build_style_us_full,
)
from src.fm_factor_panel import build_us_factor_panel
from src.fm_factor_model_us import estimate_us_factor_model
from src.fm_decompose_us import (
    _load_factor_panel_us,
    _load_factor_model_us,
    build_equal_weight_portfolio,
    decompose_portfolio_us,
    sanity_check_decomposition_us,
    _attach_sector_exposures_us,
)

# %%
from src.fm_config import (
    US_UNIVERSE_DEFAULT, US_BACKTEST_START, US_BACKTEST_END, DATA_INT
)

from src.fm_factors import (
    build_us_tier1_factors, build_us_tier2_factors,
    build_us_tier3_factors, build_style_us_full
)
from src.fm_factor_panel import build_us_factor_panel

# %%
US_TICKERS = ["NVDA","AAPL","MSFT","AMZN","GOOGL","GOOG","AVGO","META","TSLA","BRK.B",
 "LLY","JPM","WMT","ORCL","V","XOM","JNJ","MA","NFLX","ABBV",
 "COST","PLTR","BAC","AMD","PG",
 "HD","GE","CSCO","KO","CVX",
 "UNH","IBM","WFC","CAT","MS","MU","PM","AXP","TMUS","MRK",
 "GS","RTX","ABT","CRM","MCD","TMO","PEP","ISRG","LIN","AMAT"]
    #["AAPL", "MSFT", "AMZN", "GOOGL","NVDA","META"]  # change here only
START = date(2020, 10, 31)
END   = date(2025, 11, 20)

US_TICKERS, START, END
# Out:
# (['NVDA',
#   'AAPL',
#   'MSFT',
#   'AMZN',
#   'GOOGL',
#   'GOOG',
#   'AVGO',
#   'META',
#   'TSLA',
#   'BRK.B',
#   'LLY',
#   'JPM',
#   'WMT',
#   'ORCL',
#   'V',
#   'XOM',
#   'JNJ',
#   'MA',
#   'NFLX',
#   'ABBV',
#   'COST',
#   'PLTR',
#   'BAC',
#   'AMD',
#   'PG',
#   'HD',
#   'GE',
#   'CSCO',
#   'KO',
#   'CVX',
#   'UNH',
#   'IBM',
#   'WFC',
#   'CAT',
#   'MS',
#   'MU',
#   'PM',
#   'AXP',
#   'TMUS',
#   'MRK',
#   'GS',
#   'RTX',
#   'ABT',
#   'CRM',
#   'MCD',
#   'TMO',
#   'PEP',
#   'ISRG',
#   'LIN',
#   'AMAT'],
#  datetime.date(2020, 10, 31),
#  datetime.date(2025, 11, 20))

# %%
# Prices + fundamentals (US only)
# 1) Prices (SimFin)
df_us_px = load_us_prices(
    tickers=US_TICKERS,
    start=START,
    end=END,
    save=True,          # overwrites prices_us.parquet/csv
)
df_us_px.tail()
# Out:
# Dataset "us-shareprices-daily" on disk (14 days old).
# - Loading from disk ...
# c:\Users\quantbase\.conda\envs\factmod-311\Lib\site-packages\simfin\load.py:154: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv(path, sep=';', header=0,
# Done!
# [US] Saved 49,008 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\prices_us.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\prices_us.csv
#       ticker       date  SimFinId    open    high     low   close  adj_close  \
# 49003    XOM 2024-11-15    121214  120.40  121.24  119.13  119.31     115.08
# 49004    XOM 2024-11-18    121214  119.79  120.62  119.27  120.31     116.04
# 49005    XOM 2024-11-19    121214  119.75  119.75  118.20  118.63     114.42
# 49006    XOM 2024-11-20    121214  119.17  120.47  118.64  120.32     116.05
# 49007    XOM 2024-11-21    121214  121.08  122.55  120.27  121.93     117.61
#
#          volume  Dividend  shares_outstanding
# 49003  19051713       NaN        4.395095e+09
# 49004  14243701       NaN        4.395095e+09
# 49005  11584382       NaN        4.395095e+09
# 49006  11360932       NaN        4.395095e+09
# 49007  14675422       NaN        4.395095e+09

# %%
# 2) Fundamentals (income, balance, cashflow)
df_inc = load_us_income_ttm(tickers=US_TICKERS, save=True)
df_bal = load_us_balance_ttm(tickers=US_TICKERS, save=True)
df_cf  = load_us_cashflow_ttm(tickers=US_TICKERS, save=True)
# Out:
# Dataset "us-income-ttm" on disk (14 days old).
# - Loading from disk ... Done!
# c:\Users\quantbase\.conda\envs\factmod-311\Lib\site-packages\simfin\load.py:154: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv(path, sep=';', header=0,
# [US][income_ttm] Saved 814 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\us_income_ttm.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\us_income_ttm.csv
# Dataset "us-balance-ttm" on disk (14 days old).
# - Loading from disk ...
# c:\Users\quantbase\.conda\envs\factmod-311\Lib\site-packages\simfin\load.py:154: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv(path, sep=';', header=0,
# Done!
# [US][balance_ttm] Saved 815 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\us_balance_ttm.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\us_balance_ttm.csv
# Dataset "us-cashflow-ttm" on disk (14 days old).
# - Loading from disk ... Done!
# [US][cashflow_ttm] Saved 814 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\us_cashflow_ttm.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\us_cashflow_ttm.csv
# c:\Users\quantbase\.conda\envs\factmod-311\Lib\site-packages\simfin\load.py:154: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv(path, sep=';', header=0,

# %%
df_inc.tail()
# Out:
#     ticker report_date  SimFinId Currency  Fiscal Year Fiscal Period  \
# 809    XOM  2023-09-30    121214      USD         2023            Q3
# 810    XOM  2023-12-31    121214      USD         2023            Q4
# 811    XOM  2024-03-31    121214      USD         2024            Q1
# 812    XOM  2024-06-30    121214      USD         2024            Q2
# 813    XOM  2024-09-30    121214      USD         2024            Q3
#
#     Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 809   2023-10-31    2024-11-04    4.117313e+09      4.118349e+09  ...
# 810   2024-02-28    2024-11-04    4.052000e+09      4.053036e+09  ...
# 811   2024-04-29    2025-05-05    4.026000e+09      4.027036e+09  ...
# 812   2024-08-05    2025-08-04    4.089786e+09      4.089786e+09  ...
# 813   2024-11-04    2025-11-03    4.197508e+09      4.197508e+09  ...
#
#      Non-Operating Income (Loss)  Interest Expense, Net  \
# 809                -3.451600e+10           -784000000.0
# 810                -2.347500e+10           -849000000.0
# 811                -2.317800e+10           -911000000.0
# 812                -2.185400e+10           -933000000.0
# 813                -2.087100e+10           -971000000.0
#
#      Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 809                6.100000e+10                      NaN
# 810                5.278300e+10                      NaN
# 811                4.834900e+10                      NaN
# 812                5.035800e+10                      NaN
# 813                4.968500e+10                      NaN
#
#      Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 809           61000000000                      -1.860300e+10
# 810           52783000000                      -1.542900e+10
# 811           48349000000                      -1.427200e+10
# 812           50358000000                      -1.486300e+10
# 813           49685000000                      -1.456500e+10
#
#      Income (Loss) from Continuing Operations  \
# 809                               42397000000
# 810                               37354000000
# 811                               34077000000
# 812                               35495000000
# 813                               35120000000
#
#      Net Extraordinary Gains (Losses)   Net Income  Net Income (Common)
# 809                               NaN  41130000000          41130000000
# 810                               NaN  36010000000          36010000000
# 811                               NaN  32800000000          32800000000
# 812                               NaN  34160000000          34160000000
# 813                               NaN  33700000000          33700000000
#
# [5 rows x 28 columns]

# %%
df_bal.tail()
# Out:
#     ticker report_date  SimFinId Currency  Fiscal Year Fiscal Period  \
# 810    XOM  2023-09-30    121214      USD         2023            Q3
# 811    XOM  2023-12-31    121214      USD         2023            Q4
# 812    XOM  2024-03-31    121214      USD         2024            Q1
# 813    XOM  2024-06-30    121214      USD         2024            Q2
# 814    XOM  2024-09-30    121214      USD         2024            Q3
#
#     Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 810   2023-10-31    2023-10-31    4.117313e+09      4.118349e+09  ...
# 811   2024-02-28    2025-02-19    4.052000e+09      4.053036e+09  ...
# 812   2024-04-29    2024-04-29    4.026000e+09      4.027036e+09  ...
# 813   2024-08-05    2024-08-05    4.089786e+09      4.089786e+09  ...
# 814   2024-11-04    2024-11-04    4.197508e+09      4.197508e+09  ...
#
#      Short Term Debt  Total Current Liabilities  Long Term Debt  \
# 810     4.743000e+09               7.118600e+10    3.651000e+10
# 811     4.090000e+09               6.531600e+10    3.748300e+10
# 812     8.227000e+09               7.192100e+10    3.221300e+10
# 813     6.621000e+09               7.076300e+10    3.656500e+10
# 814     5.632000e+09               6.999300e+10    3.691800e+10
#
#      Total Noncurrent Liabilities  Total Liabilities  \
# 810                  9.354000e+10       1.647260e+11
# 811                  9.846300e+10       1.637790e+11
# 812                  9.294500e+10       1.648660e+11
# 813                  1.136780e+11       1.844410e+11
# 814                  1.155230e+11       1.855160e+11
#
#      Share Capital & Additional Paid-In Capital  Treasury Stock  \
# 810                                1.616500e+10   -2.535120e+11
# 811                                1.778100e+10   -2.549170e+11
# 812                                1.797100e+10   -2.578910e+11
# 813                                4.678100e+10   -2.284830e+11
# 814                                4.693600e+10   -2.340490e+11
#
#      Retained Earnings  Total Equity  Total Liabilities & Equity
# 810       4.501380e+11  2.075330e+11                372259000000
# 811       4.539270e+11  2.125380e+11                376317000000
# 812       4.583390e+11  2.130520e+11                377918000000
# 813       4.632940e+11  2.762660e+11                460707000000
# 814       4.676640e+11  2.764000e+11                461916000000
#
# [5 rows x 30 columns]

# %%
df_cf.tail()
# Out:
#     ticker report_date  SimFinId Currency  Fiscal Year Fiscal Period  \
# 809    XOM  2023-09-30    121214      USD         2023            Q3
# 810    XOM  2023-12-31    121214      USD         2023            Q4
# 811    XOM  2024-03-31    121214      USD         2024            Q1
# 812    XOM  2024-06-30    121214      USD         2024            Q2
# 813    XOM  2024-09-30    121214      USD         2024            Q3
#
#     Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 809   2023-10-31    2024-08-05    4.117313e+09      4.118349e+09  ...
# 810   2024-02-28    2024-11-04    4.052000e+09      4.053036e+09  ...
# 811   2024-04-29    2025-05-05    4.026000e+09      4.027036e+09  ...
# 812   2024-08-05    2025-05-05    4.089786e+09      4.089786e+09  ...
# 813   2024-11-04    2025-08-04    4.197508e+09      4.197508e+09  ...
#
#      Net Cash from Operating Activities  Change in Fixed Assets & Intangibles  \
# 809                         59308000000                         -2.147400e+10
# 810                         55369000000                         -2.191900e+10
# 811                         53692000000                         -2.158100e+10
# 812                         54869000000                         -2.245700e+10
# 813                         56475000000                         -2.369700e+10
#
#      Net Change in Long Term Investment  \
# 809                        4.391000e+09
# 810                        4.078000e+09
# 811                        3.927000e+09
# 812                        3.566000e+09
# 813                        2.776000e+09
#
#      Net Cash from Acquisitions & Divestitures  \
# 809                                        0.0
# 810                                        0.0
# 811                                        0.0
# 812                                754000000.0
# 813                                754000000.0
#
#      Net Cash from Investing Activities  Dividends Paid  \
# 809                       -1.891500e+10   -1.486900e+10
# 810                       -1.927400e+10   -1.494100e+10
# 811                       -1.892600e+10   -1.501100e+10
# 812                       -1.942700e+10   -1.559500e+10
# 813                       -2.138800e+10   -1.617200e+10
#
#      Cash from (Repayment of) Debt  Cash from (Repurchase of) Equity  \
# 809                  -4.729000e+09                     -1.776700e+10
# 810                  -2.390000e+08                     -1.774800e+10
# 811                  -9.440000e+08                     -1.641900e+10
# 812                  -3.727000e+09                     -1.740500e+10
# 813                  -5.084000e+09                     -1.850500e+10
#
#      Net Cash from Financing Activities  Net Change in Cash
# 809                       -3.867900e+10          2509000000
# 810                       -3.429700e+10          1903000000
# 811                       -3.377200e+10           673000000
# 812                       -3.816600e+10         -3069000000
# 813                       -4.121300e+10         -6001000000
#
# [5 rows x 28 columns]

# %%
df_ret = build_returns_all(save=True)
df_ret.head()
# Out:
# [RETURNS] Saved 49,113 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\returns_all.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\returns_all.csv
#         date ticker market       ret
# 0 2020-11-03   AAPL     US  0.015353
# 1 2020-11-04   AAPL     US  0.040837
# 2 2020-11-05   AAPL     US  0.035494
# 3 2020-11-06   AAPL     US -0.002856
# 4 2020-11-09   AAPL     US -0.019968

# %%
df_mkt = build_mkt_cap_all(save=True)
df_mkt.tail()
# Out:
# [MKT_CAP] Saved 49,163 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\mkt_cap_all.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\mkt_cap_all.csv
# C:\Users\quantbase\Desktop\SyStrat_factmod\src\fm_returns.py:150: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all = pd.concat(frames, ignore_index=True)
#             date ticker market       mkt_cap
# 49158 2024-11-15    XOM     US  5.243787e+11
# 49159 2024-11-18    XOM     US  5.287738e+11
# 49160 2024-11-19    XOM     US  5.213901e+11
# 49161 2024-11-20    XOM     US  5.288178e+11
# 49162 2024-11-21    XOM     US  5.358939e+11

# %%
#----diagnostic----

# %%
import pandas as pd
from src.fm_config import DATA_INT

mkt = pd.read_parquet(DATA_INT / "mkt_cap_all.parquet")
print("mkt_cap_all tickers:", mkt["ticker"].unique())
print(
    mkt[mkt["market"] == "US"]
    .groupby("ticker")["mkt_cap"]
    .apply(lambda s: s.gt(0).mean())
)
# Out:
# mkt_cap_all tickers: ['AAPL' 'ABBV' 'ABT' 'AMAT' 'AMD' 'AMZN' 'AVGO' 'AXP' 'BAC' 'CAT' 'COST'
#  'CRM' 'CSCO' 'CVX' 'GE' 'GOOG' 'GS' 'HD' 'IBM' 'ISRG' 'JNJ' 'JPM' 'KO'
#  'LIN' 'LLY' 'MA' 'MCD' 'META' 'MRK' 'MS' 'MSFT' 'MU' 'NFLX' 'NVDA' 'ORCL'
#  'PEP' 'PG' 'PLTR' 'PM' 'RELIANCE' 'RTX' 'SBIN' 'TMO' 'TMUS' 'TSLA' 'UNH'
#  'V' 'WFC' 'WMT' 'XOM']
# ticker
# AAPL    1.0
# ABBV    1.0
# ABT     1.0
# AMAT    1.0
# AMD     1.0
# AMZN    1.0
# AVGO    1.0
# AXP     1.0
# BAC     1.0
# CAT     1.0
# COST    1.0
# CRM     1.0
# CSCO    1.0
# CVX     1.0
# GE      1.0
# GOOG    1.0
# GS      1.0
# HD      1.0
# IBM     1.0
# ISRG    1.0
# JNJ     1.0
# JPM     1.0
# KO      1.0
# LIN     1.0
# LLY     1.0
# MA      1.0
# MCD     1.0
# META    1.0
# MRK     1.0
# MS      1.0
# MSFT    1.0
# MU      1.0
# NFLX    1.0
# NVDA    1.0
# ORCL    1.0
# PEP     1.0
# PG      1.0
# PLTR    1.0
# PM      1.0
# RTX     1.0
# TMO     1.0
# TMUS    1.0
# TSLA    1.0
# UNH     1.0
# V       1.0
# WFC     1.0
# WMT     1.0
# XOM     1.0
# Name: mkt_cap, dtype: float64

# %%
#----End---

# %%
# US panel + style factors
panel_us = build_us_panel(
    tickers=US_TICKERS,
    start=START,
    end=END,
    save=True,
)
panel_us.head()
# Out:
# [US_PANEL] Saved 48,960 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\funds_panel_us.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\funds_panel_us.csv
#         date ticker market       ret       mkt_cap inc_report_date  \
# 0 2020-11-03   AAPL     US  0.015353  1.877679e+12      2020-09-30
# 1 2020-11-04   AAPL     US  0.040837  1.954357e+12      2020-09-30
# 2 2020-11-05   AAPL     US  0.035494  2.023724e+12      2020-09-30
# 3 2020-11-06   AAPL     US -0.002856  2.017944e+12      2020-09-30
# 4 2020-11-09   AAPL     US -0.019968  1.977650e+12      2020-09-30
#
#    inc_SimFinId inc_Currency  inc_Fiscal Year inc_Fiscal Period  ...  \
# 0      111052.0          USD           2020.0                Q4  ...
# 1      111052.0          USD           2020.0                Q4  ...
# 2      111052.0          USD           2020.0                Q4  ...
# 3      111052.0          USD           2020.0                Q4  ...
# 4      111052.0          USD           2020.0                Q4  ...
#
#   cf_Change in Fixed Assets & Intangibles  \
# 0                           -7.309000e+09
# 1                           -7.309000e+09
# 2                           -7.309000e+09
# 3                           -7.309000e+09
# 4                           -7.309000e+09
#
#   cf_Net Change in Long Term Investment  \
# 0                          5.453000e+09
# 1                          5.453000e+09
# 2                          5.453000e+09
# 3                          5.453000e+09
# 4                          5.453000e+09
#
#    cf_Net Cash from Acquisitions & Divestitures  \
# 0                                 -1.524000e+09
# 1                                 -1.524000e+09
# 2                                 -1.524000e+09
# 3                                 -1.524000e+09
# 4                                 -1.524000e+09
#
#    cf_Net Cash from Investing Activities  cf_Dividends Paid  \
# 0                          -4.289000e+09      -1.408100e+10
# 1                          -4.289000e+09      -1.408100e+10
# 2                          -4.289000e+09      -1.408100e+10
# 3                          -4.289000e+09      -1.408100e+10
# 4                          -4.289000e+09      -1.408100e+10
#
#    cf_Cash from (Repayment of) Debt  cf_Cash from (Repurchase of) Equity  \
# 0                      2.499000e+09                        -7.235800e+10
# 1                      2.499000e+09                        -7.235800e+10
# 2                      2.499000e+09                        -7.235800e+10
# 3                      2.499000e+09                        -7.235800e+10
# 4                      2.499000e+09                        -7.235800e+10
#
#    cf_Net Cash from Financing Activities  cf_Net Change in Cash  inc_age_days
# 0                          -8.682000e+10          -1.043500e+10          34.0
# 1                          -8.682000e+10          -1.043500e+10          35.0
# 2                          -8.682000e+10          -1.043500e+10          36.0
# 3                          -8.682000e+10          -1.043500e+10          37.0
# 4                          -8.682000e+10          -1.043500e+10          40.0
#
# [5 rows x 89 columns]

# %%
panel_us.tail()
# Out:
#             date ticker market       ret       mkt_cap inc_report_date  \
# 48955 2024-11-15    XOM     US -0.010368  5.243787e+11      2024-09-30
# 48956 2024-11-18    XOM     US  0.008382  5.287738e+11      2024-09-30
# 48957 2024-11-19    XOM     US -0.013964  5.213901e+11      2024-09-30
# 48958 2024-11-20    XOM     US  0.014246  5.288178e+11      2024-09-30
# 48959 2024-11-21    XOM     US  0.013381  5.358939e+11      2024-09-30
#
#        inc_SimFinId inc_Currency  inc_Fiscal Year inc_Fiscal Period  ...  \
# 48955      121214.0          USD           2024.0                Q3  ...
# 48956      121214.0          USD           2024.0                Q3  ...
# 48957      121214.0          USD           2024.0                Q3  ...
# 48958      121214.0          USD           2024.0                Q3  ...
# 48959      121214.0          USD           2024.0                Q3  ...
#
#       cf_Change in Fixed Assets & Intangibles  \
# 48955                           -2.369700e+10
# 48956                           -2.369700e+10
# 48957                           -2.369700e+10
# 48958                           -2.369700e+10
# 48959                           -2.369700e+10
#
#       cf_Net Change in Long Term Investment  \
# 48955                          2.776000e+09
# 48956                          2.776000e+09
# 48957                          2.776000e+09
# 48958                          2.776000e+09
# 48959                          2.776000e+09
#
#        cf_Net Cash from Acquisitions & Divestitures  \
# 48955                                   754000000.0
# 48956                                   754000000.0
# 48957                                   754000000.0
# 48958                                   754000000.0
# 48959                                   754000000.0
#
#        cf_Net Cash from Investing Activities  cf_Dividends Paid  \
# 48955                          -2.138800e+10      -1.617200e+10
# 48956                          -2.138800e+10      -1.617200e+10
# 48957                          -2.138800e+10      -1.617200e+10
# 48958                          -2.138800e+10      -1.617200e+10
# 48959                          -2.138800e+10      -1.617200e+10
#
#        cf_Cash from (Repayment of) Debt  cf_Cash from (Repurchase of) Equity  \
# 48955                     -5.084000e+09                        -1.850500e+10
# 48956                     -5.084000e+09                        -1.850500e+10
# 48957                     -5.084000e+09                        -1.850500e+10
# 48958                     -5.084000e+09                        -1.850500e+10
# 48959                     -5.084000e+09                        -1.850500e+10
#
#        cf_Net Cash from Financing Activities  cf_Net Change in Cash  \
# 48955                          -4.121300e+10          -6.001000e+09
# 48956                          -4.121300e+10          -6.001000e+09
# 48957                          -4.121300e+10          -6.001000e+09
# 48958                          -4.121300e+10          -6.001000e+09
# 48959                          -4.121300e+10          -6.001000e+09
#
#        inc_age_days
# 48955          46.0
# 48956          49.0
# 48957          50.0
# 48958          51.0
# 48959          52.0
#
# [5 rows x 89 columns]

# %%
# Tiered styles
t1 = build_us_tier1_factors(save=True)
t2 = build_us_tier2_factors(save=True)
t3 = build_us_tier3_factors(save=True)
style_full = build_style_us_full(save=True)

style_full.tail()
# Out:
# [STYLE_US_T1] Saved 48,960 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\style_us_tier1.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\style_us_tier1.csv
# [STYLE_US_T2] Saved 48,960 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\style_us_tier2.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\style_us_tier2.csv
# [STYLE_US_T3] Saved 48,960 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\style_us_tier3.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\style_us_tier3.csv
# [STYLE_US_FULL] Saved 48,960 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\style_us_full.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\style_us_full.csv
#             date ticker market      SIZE       VAL       MOM      QUAL  \
# 48955 2024-11-15    XOM     US  0.351973  2.981858 -0.689703  0.597279
# 48956 2024-11-18    XOM     US  0.357501  2.957847 -0.695034  0.582786
# 48957 2024-11-19    XOM     US  0.337181  2.989019 -0.741720  0.607253
# 48958 2024-11-20    XOM     US  0.351328  2.965385 -0.712199  0.590732
# 48959 2024-11-21    XOM     US  0.359192  2.958905 -0.687759  0.590567
#
#           ROE_z      GM_z  CashEY_z   LEV_raw     LEV_z  EMA20_GAP     VOL_Z  \
# 48955 -0.417773 -1.062687  2.375030  0.401623 -0.816151  -0.093724 -0.456367
# 48956 -0.417773 -1.062687  2.354239  0.401623 -0.816151   0.004029 -0.462297
# 48957 -0.417773 -1.062687  2.391217  0.401623 -0.816151  -0.274193 -0.485213
# 48958 -0.417773 -1.062687  2.368467  0.401623 -0.816151  -0.045949 -0.483705
# 48959 -0.417773 -1.062687  2.368394  0.401623 -0.816151   0.048292 -0.492455
#
#             LIQ
# 48955  0.491498
# 48956  0.432512
# 48957  0.341094
# 48958  0.370294
# 48959  0.427053

# %%
factor_panel = build_us_factor_panel(save=True)

factor_panel.tail()
# Out:
# [FACTOR_PANEL_US] Saved 48,960 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_panel_us.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_panel_us.csv
#             date ticker market       ret       mkt_cap      SIZE       VAL  \
# 48955 2024-11-21    UNH     US -0.005012  5.498607e+11  0.388591 -0.190104
# 48956 2024-11-21      V     US  0.008166  6.390493e+11  0.560349 -0.432355
# 48957 2024-11-21    WFC     US  0.016988  2.491458e+11 -0.515954       NaN
# 48958 2024-11-21    WMT     US  0.013879  7.105010e+11  0.681456  0.077250
# 48959 2024-11-21    XOM     US  0.013381  5.358939e+11  0.359192  2.958905
#
#             MOM      QUAL     ROE_z      GM_z  CashEY_z   LEV_raw     LEV_z  \
# 48955 -0.965951 -1.657380 -0.392150 -1.465691 -0.609711  0.651013  0.271262
# 48956 -0.732878 -0.352234  0.225702       NaN -0.571953  0.583964 -0.021091
# 48957  0.496490       NaN       NaN       NaN       NaN       NaN       NaN
# 48958  0.609728 -0.837241 -0.271600 -1.373447  0.401707  0.641362  0.229180
# 48959 -0.687759  0.590567 -0.417773 -1.062687  2.368394  0.401623 -0.816151
#
#        EMA20_GAP     VOL_Z       LIQ
# 48955  -0.041688 -0.078218 -1.019331
# 48956   0.266506 -0.532514 -0.376384
# 48957   1.321984  0.838022  0.695784
# 48958   0.826325 -0.883185  0.636490
# 48959   0.048292 -0.492455  0.427053

# %%
panel = pd.read_parquet(DATA_INT / "funds_panel_us.parquet")

print("funds_panel_us tickers:", panel["ticker"].unique())
print(panel.groupby("ticker")[["ret", "mkt_cap"]].count())
# Out:
# funds_panel_us tickers: ['AAPL' 'ABBV' 'ABT' 'AMAT' 'AMD' 'AMZN' 'AVGO' 'AXP' 'BAC' 'CAT' 'COST'
#  'CRM' 'CSCO' 'CVX' 'GE' 'GOOG' 'GS' 'HD' 'IBM' 'ISRG' 'JNJ' 'JPM' 'KO'
#  'LIN' 'LLY' 'MA' 'MCD' 'META' 'MRK' 'MS' 'MSFT' 'MU' 'NFLX' 'NVDA' 'ORCL'
#  'PEP' 'PG' 'PLTR' 'PM' 'RTX' 'TMO' 'TMUS' 'TSLA' 'UNH' 'V' 'WFC' 'WMT'
#  'XOM']
#          ret  mkt_cap
# ticker
# AAPL    1020     1020
# ABBV    1020     1020
# ABT     1020     1020
# AMAT    1020     1020
# AMD     1020     1020
# AMZN    1020     1020
# AVGO    1020     1020
# AXP     1020     1020
# BAC     1020     1020
# CAT     1020     1020
# COST    1020     1020
# CRM     1020     1020
# CSCO    1020     1020
# CVX     1020     1020
# GE      1020     1020
# GOOG    1020     1020
# GS      1020     1020
# HD      1020     1020
# IBM     1020     1020
# ISRG    1020     1020
# JNJ     1020     1020
# JPM     1020     1020
# KO      1020     1020
# LIN     1020     1020
# LLY     1020     1020
# MA      1020     1020
# MCD     1020     1020
# META    1020     1020
# MRK     1020     1020
# MS      1020     1020
# MSFT    1020     1020
# MU      1020     1020
# NFLX    1020     1020
# NVDA    1020     1020
# ORCL    1020     1020
# PEP     1020     1020
# PG      1020     1020
# PLTR    1020     1020
# PM      1020     1020
# RTX     1020     1020
# TMO     1020     1020
# TMUS    1020     1020
# TSLA    1020     1020
# UNH     1020     1020
# V       1020     1020
# WFC     1020     1020
# WMT     1020     1020
# XOM     1020     1020

# %%
# %cd C:\Users\quantbase\Desktop\SyStrat_factmod
# !python -m src.fm_sector_us
# Out:
# C:\Users\quantbase\Desktop\SyStrat_factmod
# [SECTOR_US] Built sector dummies: 49 tickers, 9 sector columns.
# [SECTOR_US] Saved to:
#   C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\sector_dummies_us.parquet
#   C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\sector_dummies_us.csv
# [SECTOR_US] Head:
#   ticker  ... sector_Materials
# 0   AAPL  ...            False
# 1   MSFT  ...            False
# 2   AMZN  ...            False
# 3   META  ...            False
# 4   NVDA  ...            False
#
# [5 rows x 11 columns]

# %%
import importlib

# %%
import src.fm_factor_model_us
from src.fm_factor_model_us import estimate_us_factor_model

# %%
importlib.reload(src.fm_factor_model_us)
# Out:
# <module 'src.fm_factor_model_us' from 'C:\\Users\\quantbase\\Desktop\\SyStrat_factmod\\src\\fm_factor_model_us.py'>

# %%
out = estimate_us_factor_model(save=True)
fac_ret, eps, cov = out["factor_returns"], out["residuals"], out["factor_cov"]
# Out:
# [TORANIKO_INPUTS_US] Using 31,529 rows with complete style data and 7 style factors: ['SIZE', 'VAL', 'MOM', 'QUAL', 'EMA20_GAP', 'VOL_Z', 'LIQ']
# [TORANIKO_INPUTS_US] Sector columns used: ['sector_Communication Services', 'sector_Consumer Discretionary', 'sector_Consumer Staples', 'sector_Energy', 'sector_Financials', 'sector_Health Care', 'sector_Industrials', 'sector_Information Technology', 'sector_Materials']
# [FACTOR_MODEL_US] Saved factor returns (769 rows) to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_returns_us.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_returns_us.csv
# [FACTOR_MODEL_US] Saved residuals (769 rows) to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_residuals_us.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_residuals_us.csv
# [FACTOR_MODEL_US] Saved factor covariance matrix to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_cov_us.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_cov_us.csv

# %%
fac_ret_us, eps_us, factor_cov_us = estimate_us_factor_model(
    model_start=START,
    model_end=END,
    tickers=US_TICKERS,
    save=True,
)
# Out:
# [TORANIKO_INPUTS_US] Using 31,529 rows with complete style data and 7 style factors: ['SIZE', 'VAL', 'MOM', 'QUAL', 'EMA20_GAP', 'VOL_Z', 'LIQ']
# [TORANIKO_INPUTS_US] Sector columns used: ['sector_Communication Services', 'sector_Consumer Discretionary', 'sector_Consumer Staples', 'sector_Energy', 'sector_Financials', 'sector_Health Care', 'sector_Industrials', 'sector_Information Technology', 'sector_Materials']
# [FACTOR_MODEL_US] Saved factor returns (769 rows) to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_returns_us.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_returns_us.csv
# [FACTOR_MODEL_US] Saved residuals (769 rows) to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_residuals_us.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_residuals_us.csv
# [FACTOR_MODEL_US] Saved factor covariance matrix to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_cov_us.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_cov_us.csv

# %%
fac = pd.read_parquet(DATA_INT / "factor_returns_us.parquet")
res = pd.read_parquet(DATA_INT / "factor_residuals_us.parquet")
cov = pd.read_parquet(DATA_INT / "factor_cov_us.parquet")

# %%
fac.head()
# Out:
#               market  sector_Communication Services  \
# date
# 2021-11-02  0.001730                       0.001861
# 2021-11-03  0.004885                       0.006107
# 2021-11-04  0.007573                       0.001382
# 2021-11-05  0.005470                      -0.002796
# 2021-11-08  0.003165                      -0.005304
#
#             sector_Consumer Discretionary  sector_Consumer Staples  \
# date
# 2021-11-02                      -0.006513                 0.003607
# 2021-11-03                       0.011467                 0.001578
# 2021-11-04                       0.009735                 0.000330
# 2021-11-05                      -0.004071                -0.004284
# 2021-11-08                      -0.011729                -0.013222
#
#             sector_Energy  sector_Financials  sector_Health Care  \
# date
# 2021-11-02      -0.011131          -0.014072            0.005852
# 2021-11-03      -0.009858          -0.006224            0.002056
# 2021-11-04      -0.001522           0.002628           -0.003737
# 2021-11-05       0.004646           0.017368           -0.016948
# 2021-11-08       0.004207           0.007482            0.001224
#
#             sector_Industrials  sector_Information Technology  \
# date
# 2021-11-02           -0.000519                       0.008403
# 2021-11-03           -0.004620                       0.001815
# 2021-11-04           -0.011362                       0.000710
# 2021-11-05            0.013672                      -0.003595
# 2021-11-08            0.001348                       0.002472
#
#             sector_Materials  EMA20_GAP       LIQ       MOM      QUAL  \
# date
# 2021-11-02          0.012513   0.004956  0.001394  0.001188  0.004257
# 2021-11-03         -0.002321   0.003788  0.000185 -0.004937 -0.002133
# 2021-11-04          0.001836   0.006075  0.001545 -0.007080 -0.000148
# 2021-11-05         -0.003992   0.001548  0.002584 -0.001303 -0.001083
# 2021-11-08          0.013522   0.005164 -0.002133 -0.005546 -0.000277
#
#                 SIZE       VAL     VOL_Z
# date
# 2021-11-02  0.000501 -0.002307 -0.006729
# 2021-11-03  0.002700  0.000287  0.002906
# 2021-11-04  0.001171 -0.001204  0.003309
# 2021-11-05  0.000277  0.005134 -0.001106
# 2021-11-08 -0.000367  0.003518  0.005161

# %%
fac.columns
# Out:
# Index(['market', 'sector_Communication Services',
#        'sector_Consumer Discretionary', 'sector_Consumer Staples',
#        'sector_Energy', 'sector_Financials', 'sector_Health Care',
#        'sector_Industrials', 'sector_Information Technology',
#        'sector_Materials', 'EMA20_GAP', 'LIQ', 'MOM', 'QUAL', 'SIZE', 'VAL',
#        'VOL_Z'],
#       dtype='object')

# %%
fac.describe().T
# Out:
#                                count      mean       std       min       25%  \
# market                         769.0  0.000631  0.010248 -0.041246 -0.004548
# sector_Communication Services  769.0  0.000082  0.008221 -0.030007 -0.005304
# sector_Consumer Discretionary  769.0 -0.000341  0.007701 -0.027488 -0.005106
# sector_Consumer Staples        769.0 -0.000055  0.007401 -0.029029 -0.004558
# sector_Energy                  769.0  0.000220  0.010722 -0.035035 -0.007814
# sector_Financials              769.0 -0.000049  0.007409 -0.025135 -0.004195
# sector_Health Care             769.0 -0.000133  0.006433 -0.020434 -0.003982
# sector_Industrials             769.0  0.000241  0.006824 -0.031472 -0.003866
# sector_Information Technology  769.0 -0.000004  0.007709 -0.029852 -0.004864
# sector_Materials               769.0  0.000039  0.007876 -0.028269 -0.004657
# EMA20_GAP                      769.0  0.004262  0.004304 -0.008325  0.001703
# LIQ                            769.0 -0.000120  0.002858 -0.014272 -0.002034
# MOM                            769.0 -0.000041  0.003242 -0.016467 -0.001881
# QUAL                           769.0 -0.000007  0.001957 -0.006031 -0.001242
# SIZE                           769.0  0.000213  0.005578 -0.020686 -0.003009
# VAL                            769.0  0.000145  0.002703 -0.007816 -0.001485
# VOL_Z                          769.0  0.000053  0.006043 -0.027716 -0.003348
#
#                                     50%       75%       max
# market                         0.000447  0.005992  0.048948
# sector_Communication Services  0.000540  0.005196  0.039662
# sector_Consumer Discretionary -0.000435  0.004703  0.027811
# sector_Consumer Staples       -0.000054  0.003986  0.034834
# sector_Energy                 -0.000394  0.007914  0.034529
# sector_Financials              0.000131  0.004246  0.025687
# sector_Health Care            -0.000516  0.003558  0.023977
# sector_Industrials             0.000207  0.004831  0.021021
# sector_Information Technology  0.000191  0.004788  0.033216
# sector_Materials               0.000247  0.004451  0.024642
# EMA20_GAP                      0.003773  0.006118  0.040246
# LIQ                           -0.000158  0.001683  0.009683
# MOM                           -0.000138  0.001987  0.012945
# QUAL                          -0.000009  0.001216  0.005994
# SIZE                           0.000205  0.003533  0.029631
# VAL                           -0.000009  0.001879  0.009273
# VOL_Z                         -0.000074  0.003054  0.028356

# %%
res.head()
# Out:
#                 AAPL      ABBV       ABT      AMAT       AMD      AMZN  \
# date
# 2021-11-02 -0.006431 -0.001015 -0.021667  0.008326  0.008354  0.005403
# 2021-11-03 -0.005051  0.001948 -0.000927  0.010386  0.004439 -0.004755
# 2021-11-04 -0.017521 -0.012423 -0.003681  0.020891 -0.003395 -0.004249
# 2021-11-05 -0.004172  0.011541 -0.011295  0.020160 -0.012435  0.006548
# 2021-11-08 -0.004443 -0.019108  0.013664 -0.012593 -0.002504  0.002205
#
#                 AVGO       CAT      COST       CRM  ...        PG      PLTR  \
# date                                                ...
# 2021-11-02 -0.001319  0.015664  0.006757 -0.011137  ... -0.002068 -0.009491
# 2021-11-03  0.004792 -0.006868 -0.000872 -0.010782  ... -0.001101  0.009628
# 2021-11-04  0.001646  0.005952  0.013694  0.000652  ... -0.006916  0.010412
# 2021-11-05  0.014140 -0.008710 -0.004609 -0.000225  ...  0.000751 -0.005648
# 2021-11-08 -0.005466  0.007514 -0.005539 -0.002137  ...  0.004835  0.016178
#
#                  RTX       TMO      TMUS      TSLA       UNH         V  \
# date
# 2021-11-02 -0.000812 -0.005403  0.000222 -0.006897 -0.008097  0.012937
# 2021-11-03  0.015406 -0.002225  0.010074 -0.011607 -0.001380 -0.002739
# 2021-11-04  0.011789 -0.011525 -0.006524 -0.019582 -0.008887 -0.004371
# 2021-11-05  0.000024 -0.008670 -0.007044 -0.005239  0.007766  0.001889
# 2021-11-08 -0.005950  0.001956 -0.022344 -0.005864  0.004542  0.007225
#
#                  WMT       XOM
# date
# 2021-11-02 -0.010142 -0.001554
# 2021-11-03 -0.008496  0.006686
# 2021-11-04 -0.005298  0.010368
# 2021-11-05 -0.013787 -0.003583
# 2021-11-08  0.006297  0.007545
#
# [5 rows x 41 columns]

# %%
res.columns
# Out:
# Index(['AAPL', 'ABBV', 'ABT', 'AMAT', 'AMD', 'AMZN', 'AVGO', 'CAT', 'COST',
#        'CRM', 'CSCO', 'CVX', 'GE', 'GOOG', 'HD', 'IBM', 'ISRG', 'JNJ', 'KO',
#        'LIN', 'LLY', 'MA', 'MCD', 'META', 'MRK', 'MSFT', 'MU', 'NFLX', 'NVDA',
#        'ORCL', 'PEP', 'PG', 'PLTR', 'RTX', 'TMO', 'TMUS', 'TSLA', 'UNH', 'V',
#        'WMT', 'XOM'],
#       dtype='object')

# %%
res.describe().T
# Out:
#       count      mean       std       min       25%       50%       75%  \
# AAPL  769.0 -0.000723  0.014606 -0.066325 -0.009727 -0.000633  0.007719
# ABBV  769.0  0.000340  0.007931 -0.025281 -0.004755  0.000179  0.005625
# ABT   769.0  0.000226  0.009410 -0.028201 -0.005293 -0.000014  0.005872
# AMAT  769.0  0.000350  0.009724 -0.029194 -0.006402  0.000092  0.006700
# AMD   769.0  0.000370  0.010014 -0.039911 -0.005559  0.000105  0.006475
# AMZN  769.0 -0.000107  0.011454 -0.039210 -0.007085 -0.000109  0.006941
# AVGO  769.0 -0.000705  0.008812 -0.029343 -0.006214 -0.000673  0.004641
# CAT   769.0 -0.000256  0.009374 -0.031467 -0.006148 -0.000209  0.005486
# COST  769.0 -0.000012  0.008895 -0.032882 -0.005612 -0.000137  0.005483
# CRM   769.0  0.000389  0.010550 -0.038776 -0.006457  0.000300  0.006882
# CSCO  769.0 -0.000083  0.008429 -0.031477 -0.005544 -0.000358  0.005182
# CVX   769.0 -0.000535  0.010002 -0.036813 -0.007521 -0.000383  0.006586
# GE    769.0 -0.000420  0.011323 -0.044610 -0.006223 -0.000407  0.006111
# GOOG  769.0 -0.000175  0.012328 -0.057839 -0.007853 -0.000569  0.006812
# HD    769.0  0.000599  0.009691 -0.036473 -0.005322  0.000530  0.006932
# IBM   769.0 -0.000154  0.008520 -0.038359 -0.005701  0.000105  0.005071
# ISRG  769.0  0.000224  0.013391 -0.053035 -0.007578  0.000289  0.007645
# JNJ   769.0 -0.000184  0.006729 -0.022034 -0.004405 -0.000061  0.003982
# KO    769.0  0.000067  0.007972 -0.028446 -0.004487  0.000243  0.004639
# LIN   769.0 -0.000016  0.006234 -0.024805 -0.003348 -0.000143  0.003166
# LLY   769.0 -0.000415  0.007834 -0.029703 -0.005378 -0.000426  0.004588
# MA    769.0 -0.000177  0.006183 -0.032296 -0.003931  0.000177  0.003525
# MCD   769.0  0.000209  0.009023 -0.032723 -0.005547  0.000501  0.005664
# META  769.0 -0.000528  0.012347 -0.056351 -0.007898 -0.000635  0.007073
# MRK   769.0  0.000344  0.007599 -0.032342 -0.004402  0.000410  0.004795
# MSFT  769.0 -0.000341  0.013836 -0.073556 -0.008026 -0.000533  0.007050
# MU    769.0  0.000400  0.011394 -0.036073 -0.007075  0.000501  0.007069
# NFLX  769.0 -0.000441  0.011400 -0.038779 -0.007060 -0.000742  0.005633
# NVDA  769.0 -0.000837  0.012008 -0.047391 -0.008048 -0.001279  0.005695
# ORCL  769.0 -0.000341  0.010429 -0.054343 -0.006270  0.000084  0.005935
# PEP   769.0  0.000101  0.007443 -0.026810 -0.004442  0.000343  0.004743
# PG    769.0  0.000083  0.006161 -0.028634 -0.003855  0.000072  0.003946
# PLTR  769.0  0.000229  0.015556 -0.048314 -0.009491  0.001105  0.010118
# RTX   769.0 -0.000198  0.009409 -0.031528 -0.006002 -0.000197  0.005036
# TMO   769.0  0.000071  0.010134 -0.034204 -0.005754 -0.000121  0.006184
# TMUS  769.0 -0.000306  0.010220 -0.039932 -0.006847 -0.000266  0.005894
# TSLA  769.0  0.000525  0.013786 -0.059331 -0.007858  0.000340  0.008789
# UNH   769.0 -0.000122  0.007543 -0.025512 -0.005151 -0.000329  0.004630
# V     769.0 -0.000136  0.005796 -0.024608 -0.003300 -0.000188  0.003067
# WMT   769.0 -0.000302  0.006935 -0.030581 -0.004273 -0.000355  0.003729
# XOM   769.0 -0.000838  0.009699 -0.038069 -0.006757 -0.000366  0.005519
#
#            max
# AAPL  0.050208
# ABBV  0.031796
# ABT   0.036504
# AMAT  0.052220
# AMD   0.050947
# AMZN  0.043425
# AVGO  0.036650
# CAT   0.034421
# COST  0.038326
# CRM   0.048543
# CSCO  0.035751
# CVX   0.039920
# GE    0.041729
# GOOG  0.058532
# HD    0.034324
# IBM   0.035333
# ISRG  0.054026
# JNJ   0.025784
# KO    0.037559
# LIN   0.025947
# LLY   0.025267
# MA    0.021550
# MCD   0.029674
# META  0.044009
# MRK   0.032687
# MSFT  0.053525
# MU    0.049008
# NFLX  0.046216
# NVDA  0.041510
# ORCL  0.038906
# PEP   0.027808
# PG    0.019965
# PLTR  0.059948
# RTX   0.038981
# TMO   0.044857
# TMUS  0.038611
# TSLA  0.053460
# UNH   0.032912
# V     0.023777
# WMT   0.043099
# XOM   0.028687

# %%
cov
# Out:
#                                  market  sector_Communication Services  \
# market                         0.026463                       0.008414
# sector_Communication Services  0.008414                       0.017032
# sector_Consumer Discretionary  0.008487                       0.008005
# sector_Consumer Staples       -0.010900                      -0.006311
# sector_Energy                 -0.006162                      -0.011110
# sector_Financials              0.001840                      -0.001625
# sector_Health Care            -0.008899                      -0.005409
# sector_Industrials            -0.001306                      -0.005511
# sector_Information Technology  0.009428                       0.009553
# sector_Materials              -0.000903                      -0.004623
# EMA20_GAP                     -0.000682                      -0.001286
# LIQ                           -0.002970                      -0.001674
# MOM                            0.001588                       0.000081
# QUAL                          -0.000051                       0.000564
# SIZE                           0.012927                       0.006940
# VAL                            0.000020                      -0.000693
# VOL_Z                          0.010845                       0.006388
#
#                                sector_Consumer Discretionary  \
# market                                              0.008487
# sector_Communication Services                       0.008005
# sector_Consumer Discretionary                       0.014943
# sector_Consumer Staples                            -0.005282
# sector_Energy                                      -0.009017
# sector_Financials                                  -0.002296
# sector_Health Care                                 -0.005830
# sector_Industrials                                 -0.003897
# sector_Information Technology                       0.008678
# sector_Materials                                   -0.005303
# EMA20_GAP                                          -0.000896
# LIQ                                                -0.000335
# MOM                                                -0.000393
# QUAL                                               -0.000558
# SIZE                                                0.005760
# VAL                                                -0.000930
# VOL_Z                                               0.006528
#
#                                sector_Consumer Staples  sector_Energy  \
# market                                       -0.010900      -0.006162
# sector_Communication Services                -0.006311      -0.011110
# sector_Consumer Discretionary                -0.005282      -0.009017
# sector_Consumer Staples                       0.013803       0.000168
# sector_Energy                                 0.000168       0.028973
# sector_Financials                            -0.001979      -0.003319
# sector_Health Care                            0.007202       0.000771
# sector_Industrials                           -0.001327       0.005847
# sector_Information Technology                -0.007071      -0.010244
# sector_Materials                              0.000797      -0.002069
# EMA20_GAP                                     0.000286       0.001148
# LIQ                                           0.001683       0.001510
# MOM                                          -0.001047       0.001161
# QUAL                                         -0.000172      -0.000726
# SIZE                                         -0.006198      -0.005122
# VAL                                          -0.000764       0.004336
# VOL_Z                                        -0.007791      -0.002868
#
#                                sector_Financials  sector_Health Care  \
# market                                  0.001840           -0.008899
# sector_Communication Services          -0.001625           -0.005409
# sector_Consumer Discretionary          -0.002296           -0.005830
# sector_Consumer Staples                -0.001979            0.007202
# sector_Energy                          -0.003319            0.000771
# sector_Financials                       0.013833           -0.001156
# sector_Health Care                     -0.001156            0.010429
# sector_Industrials                     -0.001067           -0.000976
# sector_Information Technology          -0.001986           -0.005953
# sector_Materials                       -0.000404            0.000922
# EMA20_GAP                               0.000544            0.000513
# LIQ                                    -0.000837            0.000282
# MOM                                    -0.000710           -0.000328
# QUAL                                    0.000314            0.000627
# SIZE                                    0.000697           -0.004763
# VAL                                    -0.001165           -0.000888
# VOL_Z                                   0.000178           -0.005522
#
#                                sector_Industrials  \
# market                                  -0.001306
# sector_Communication Services           -0.005511
# sector_Consumer Discretionary           -0.003897
# sector_Consumer Staples                 -0.001327
# sector_Energy                            0.005847
# sector_Financials                       -0.001067
# sector_Health Care                      -0.000976
# sector_Industrials                       0.011735
# sector_Information Technology           -0.003902
# sector_Materials                        -0.000902
# EMA20_GAP                                0.000131
# LIQ                                      0.000276
# MOM                                      0.000610
# QUAL                                    -0.000670
# SIZE                                    -0.002246
# VAL                                      0.001381
# VOL_Z                                   -0.001545
#
#                                sector_Information Technology  \
# market                                              0.009428
# sector_Communication Services                       0.009553
# sector_Consumer Discretionary                       0.008678
# sector_Consumer Staples                            -0.007071
# sector_Energy                                      -0.010244
# sector_Financials                                  -0.001986
# sector_Health Care                                 -0.005953
# sector_Industrials                                 -0.003902
# sector_Information Technology                       0.014976
# sector_Materials                                   -0.004050
# EMA20_GAP                                          -0.000444
# LIQ                                                -0.000302
# MOM                                                 0.001067
# QUAL                                                0.000245
# SIZE                                                0.006387
# VAL                                                -0.001150
# VOL_Z                                               0.006636
#
#                                sector_Materials  EMA20_GAP       LIQ  \
# market                                -0.000903  -0.000682 -0.002970
# sector_Communication Services         -0.004623  -0.001286 -0.001674
# sector_Consumer Discretionary         -0.005303  -0.000896 -0.000335
# sector_Consumer Staples                0.000797   0.000286  0.001683
# sector_Energy                         -0.002069   0.001148  0.001510
# sector_Financials                     -0.000404   0.000544 -0.000837
# sector_Health Care                     0.000922   0.000513  0.000282
# sector_Industrials                    -0.000902   0.000131  0.000276
# sector_Information Technology         -0.004050  -0.000444 -0.000302
# sector_Materials                       0.015633   0.000004 -0.000602
# EMA20_GAP                              0.000004   0.004668  0.000031
# LIQ                                   -0.000602   0.000031  0.002058
# MOM                                   -0.000442  -0.000221 -0.000093
# QUAL                                   0.000376  -0.000132 -0.000193
# SIZE                                  -0.001455  -0.000433 -0.002209
# VAL                                   -0.000127   0.000125 -0.000112
# VOL_Z                                 -0.002004  -0.000683 -0.001557
#
#                                     MOM      QUAL      SIZE       VAL  \
# market                         0.001588 -0.000051  0.012927  0.000020
# sector_Communication Services  0.000081  0.000564  0.006940 -0.000693
# sector_Consumer Discretionary -0.000393 -0.000558  0.005760 -0.000930
# sector_Consumer Staples       -0.001047 -0.000172 -0.006198 -0.000764
# sector_Energy                  0.001161 -0.000726 -0.005122  0.004336
# sector_Financials             -0.000710  0.000314  0.000697 -0.001165
# sector_Health Care            -0.000328  0.000627 -0.004763 -0.000888
# sector_Industrials             0.000610 -0.000670 -0.002246  0.001381
# sector_Information Technology  0.001067  0.000245  0.006387 -0.001150
# sector_Materials              -0.000442  0.000376 -0.001455 -0.000127
# EMA20_GAP                     -0.000221 -0.000132 -0.000433  0.000125
# LIQ                           -0.000093 -0.000193 -0.002209 -0.000112
# MOM                            0.002648 -0.000087  0.000481  0.000100
# QUAL                          -0.000087  0.000965  0.000052 -0.000534
# SIZE                           0.000481  0.000052  0.007841 -0.000082
# VAL                            0.000100 -0.000534 -0.000082  0.001841
# VOL_Z                          0.000503 -0.000067  0.006198 -0.000117
#
#                                   VOL_Z
# market                         0.010845
# sector_Communication Services  0.006388
# sector_Consumer Discretionary  0.006528
# sector_Consumer Staples       -0.007791
# sector_Energy                 -0.002868
# sector_Financials              0.000178
# sector_Health Care            -0.005522
# sector_Industrials            -0.001545
# sector_Information Technology  0.006636
# sector_Materials              -0.002004
# EMA20_GAP                     -0.000683
# LIQ                           -0.001557
# MOM                            0.000503
# QUAL                          -0.000067
# SIZE                           0.006198
# VAL                           -0.000117
# VOL_Z                          0.009204

# %%
cov.equals(cov.T)      # check - should be True or very close
# Out:
# True

# %%
cov.index, cov.columns # same labels
# Out:
# (Index(['market', 'sector_Communication Services',
#         'sector_Consumer Discretionary', 'sector_Consumer Staples',
#         'sector_Energy', 'sector_Financials', 'sector_Health Care',
#         'sector_Industrials', 'sector_Information Technology',
#         'sector_Materials', 'EMA20_GAP', 'LIQ', 'MOM', 'QUAL', 'SIZE', 'VAL',
#         'VOL_Z'],
#        dtype='object'),
#  Index(['market', 'sector_Communication Services',
#         'sector_Consumer Discretionary', 'sector_Consumer Staples',
#         'sector_Energy', 'sector_Financials', 'sector_Health Care',
#         'sector_Industrials', 'sector_Information Technology',
#         'sector_Materials', 'EMA20_GAP', 'LIQ', 'MOM', 'QUAL', 'SIZE', 'VAL',
#         'VOL_Z'],
#        dtype='object'))

# %%
diag = cov.values.diagonal()
vol = np.sqrt(diag)    # annual implied factor vols
pd.Series(vol, index=cov.index)
# Out:
# market                           0.162676
# sector_Communication Services    0.130505
# sector_Consumer Discretionary    0.122243
# sector_Consumer Staples          0.117488
# sector_Energy                    0.170214
# sector_Financials                0.117612
# sector_Health Care               0.102125
# sector_Industrials               0.108330
# sector_Information Technology    0.122377
# sector_Materials                 0.125032
# EMA20_GAP                        0.068326
# LIQ                              0.045368
# MOM                              0.051457
# QUAL                             0.031061
# SIZE                             0.088548
# VAL                              0.042912
# VOL_Z                            0.095935
# dtype: float64

# %%
std = np.sqrt(diag)
corr = cov / std[:, None] / std[None, :]     #turn covariance into correlation
corr
# Out:
#                                  market  sector_Communication Services  \
# market                         1.000000                       0.396326
# sector_Communication Services  0.396326                       1.000000
# sector_Consumer Discretionary  0.426796                       0.501758
# sector_Consumer Staples       -0.570304                      -0.411614
# sector_Energy                 -0.222521                      -0.500127
# sector_Financials              0.096168                      -0.105897
# sector_Health Care            -0.535671                      -0.405876
# sector_Industrials            -0.074105                      -0.389785
# sector_Information Technology  0.473588                       0.598140
# sector_Materials              -0.044380                      -0.283298
# EMA20_GAP                     -0.061380                      -0.144166
# LIQ                           -0.402461                      -0.282717
# MOM                            0.189726                       0.012007
# QUAL                          -0.010147                       0.139197
# SIZE                           0.897426                       0.600574
# VAL                            0.002927                      -0.123702
# VOL_Z                          0.694922                       0.510183
#
#                                sector_Consumer Discretionary  \
# market                                              0.426796
# sector_Communication Services                       0.501758
# sector_Consumer Discretionary                       1.000000
# sector_Consumer Staples                            -0.367801
# sector_Energy                                      -0.433358
# sector_Financials                                  -0.159720
# sector_Health Care                                 -0.467021
# sector_Industrials                                 -0.294274
# sector_Information Technology                       0.580122
# sector_Materials                                   -0.346985
# EMA20_GAP                                          -0.107273
# LIQ                                                -0.060437
# MOM                                                -0.062406
# QUAL                                               -0.146995
# SIZE                                                0.532100
# VAL                                                -0.177363
# VOL_Z                                               0.556672
#
#                                sector_Consumer Staples  sector_Energy  \
# market                                       -0.570304      -0.222521
# sector_Communication Services                -0.411614      -0.500127
# sector_Consumer Discretionary                -0.367801      -0.433358
# sector_Consumer Staples                       1.000000       0.008407
# sector_Energy                                 0.008407       1.000000
# sector_Financials                            -0.143185      -0.165805
# sector_Health Care                            0.600209       0.044382
# sector_Industrials                           -0.104273       0.317073
# sector_Information Technology                -0.491805      -0.491788
# sector_Materials                              0.054271      -0.097214
# EMA20_GAP                                     0.035622       0.098706
# LIQ                                           0.315727       0.195490
# MOM                                          -0.173155       0.132595
# QUAL                                         -0.047079      -0.137272
# SIZE                                         -0.595818      -0.339841
# VAL                                          -0.151581       0.593575
# VOL_Z                                        -0.691265      -0.175622
#
#                                sector_Financials  sector_Health Care  \
# market                                  0.096168           -0.535671
# sector_Communication Services          -0.105897           -0.405876
# sector_Consumer Discretionary          -0.159720           -0.467021
# sector_Consumer Staples                -0.143185            0.600209
# sector_Energy                          -0.165805            0.044382
# sector_Financials                       1.000000           -0.096234
# sector_Health Care                     -0.096234            1.000000
# sector_Industrials                     -0.083739           -0.088179
# sector_Information Technology          -0.138007           -0.476325
# sector_Materials                       -0.027471            0.072177
# EMA20_GAP                               0.067708            0.073481
# LIQ                                    -0.156814            0.060840
# MOM                                    -0.117272           -0.062443
# QUAL                                    0.085864            0.197697
# SIZE                                    0.066967           -0.526673
# VAL                                    -0.230883           -0.202546
# VOL_Z                                   0.015798           -0.563583
#
#                                sector_Industrials  \
# market                                  -0.074105
# sector_Communication Services           -0.389785
# sector_Consumer Discretionary           -0.294274
# sector_Consumer Staples                 -0.104273
# sector_Energy                            0.317073
# sector_Financials                       -0.083739
# sector_Health Care                      -0.088179
# sector_Industrials                       1.000000
# sector_Information Technology           -0.294362
# sector_Materials                        -0.066629
# EMA20_GAP                                0.017643
# LIQ                                      0.056162
# MOM                                      0.109461
# QUAL                                    -0.199167
# SIZE                                    -0.234118
# VAL                                      0.297107
# VOL_Z                                   -0.148664
#
#                                sector_Information Technology  \
# market                                              0.473588
# sector_Communication Services                       0.598140
# sector_Consumer Discretionary                       0.580122
# sector_Consumer Staples                            -0.491805
# sector_Energy                                      -0.491788
# sector_Financials                                  -0.138007
# sector_Health Care                                 -0.476325
# sector_Industrials                                 -0.294362
# sector_Information Technology                       1.000000
# sector_Materials                                   -0.264718
# EMA20_GAP                                          -0.053091
# LIQ                                                -0.054440
# MOM                                                 0.169507
# QUAL                                                0.064523
# SIZE                                                0.589417
# VAL                                                -0.218986
# VOL_Z                                               0.565212
#
#                                sector_Materials  EMA20_GAP       LIQ  \
# market                                -0.044380  -0.061380 -0.402461
# sector_Communication Services         -0.283298  -0.144166 -0.282717
# sector_Consumer Discretionary         -0.346985  -0.107273 -0.060437
# sector_Consumer Staples                0.054271   0.035622  0.315727
# sector_Energy                         -0.097214   0.098706  0.195490
# sector_Financials                     -0.027471   0.067708 -0.156814
# sector_Health Care                     0.072177   0.073481  0.060840
# sector_Industrials                    -0.066629   0.017643  0.056162
# sector_Information Technology         -0.264718  -0.053091 -0.054440
# sector_Materials                       1.000000   0.000478 -0.106187
# EMA20_GAP                              0.000478   1.000000  0.009913
# LIQ                                   -0.106187   0.009913  1.000000
# MOM                                   -0.068753  -0.062984 -0.040034
# QUAL                                   0.096705  -0.061988 -0.136741
# SIZE                                  -0.131447  -0.071588 -0.549771
# VAL                                   -0.023578   0.042493 -0.057461
# VOL_Z                                 -0.167065  -0.104224 -0.357632
#
#                                     MOM      QUAL      SIZE       VAL  \
# market                         0.189726 -0.010147  0.897426  0.002927
# sector_Communication Services  0.012007  0.139197  0.600574 -0.123702
# sector_Consumer Discretionary -0.062406 -0.146995  0.532100 -0.177363
# sector_Consumer Staples       -0.173155 -0.047079 -0.595818 -0.151581
# sector_Energy                  0.132595 -0.137272 -0.339841  0.593575
# sector_Financials             -0.117272  0.085864  0.066967 -0.230883
# sector_Health Care            -0.062443  0.197697 -0.526673 -0.202546
# sector_Industrials             0.109461 -0.199167 -0.234118  0.297107
# sector_Information Technology  0.169507  0.064523  0.589417 -0.218986
# sector_Materials              -0.068753  0.096705 -0.131447 -0.023578
# EMA20_GAP                     -0.062984 -0.061988 -0.071588  0.042493
# LIQ                           -0.040034 -0.136741 -0.549771 -0.057461
# MOM                            1.000000 -0.054734  0.105616  0.045116
# QUAL                          -0.054734  1.000000  0.018834 -0.400974
# SIZE                           0.105616  0.018834  1.000000 -0.021574
# VAL                            0.045116 -0.400974 -0.021574  1.000000
# VOL_Z                          0.101802 -0.022363  0.729612 -0.028320
#
#                                   VOL_Z
# market                         0.694922
# sector_Communication Services  0.510183
# sector_Consumer Discretionary  0.556672
# sector_Consumer Staples       -0.691265
# sector_Energy                 -0.175622
# sector_Financials              0.015798
# sector_Health Care            -0.563583
# sector_Industrials            -0.148664
# sector_Information Technology  0.565212
# sector_Materials              -0.167065
# EMA20_GAP                     -0.104224
# LIQ                           -0.357632
# MOM                            0.101802
# QUAL                          -0.022363
# SIZE                           0.729612
# VAL                           -0.028320
# VOL_Z                          1.000000

# %%
#---------Decomp

# %%
# factor panel (no sectors needed; helper will attach them inside decompose)
factor_panel = _load_factor_panel_us()  # funds_panel + style factors

# factor model outputs
factor_returns, residuals = _load_factor_model_us()

# %%
tickers_model = list(residuals.columns)   # e.g. AAPL, ABBV, ...
dates_model   = factor_returns.index      # e.g. 2021-11-02 ... 2021-XX-YY

weights_eq = build_equal_weight_portfolio(
    tickers=tickers_model,
    dates=dates_model,
)

# %%
# 2) Attach sector exposures so columns match the sector_* factors
factor_panel_with_sectors = _attach_sector_exposures_us(
    panel=factor_panel,
    factor_returns=factor_returns,
)

factor_panel_with_sectors.to_csv(DATA_INT / "factor_panel_us_with_sectors.csv")
factor_panel_with_sectors.to_parquet(DATA_INT / "factor_panel_us_with_sectors.parquet")

# %%
# 3) Quick sanity check
factor_panel_with_sectors.head()
# Out:
#         date ticker market       ret       mkt_cap      SIZE       VAL  MOM  \
# 0 2020-11-03   AAPL     US  0.015353  1.877679e+12  2.519633 -0.458390  NaN
# 1 2020-11-03   ABBV     US -0.003286  1.552911e+11 -0.214317  0.767764  NaN
# 2 2020-11-03    ABT     US  0.019352  1.941799e+11  0.030817 -0.570250  NaN
# 3 2020-11-03   AMAT     US  0.024863  5.651262e+10 -1.323079  0.695128  NaN
# 4 2020-11-03    AMD     US  0.025167  9.210366e+10 -0.787310 -1.237910  NaN
#
#        QUAL     ROE_z  ...       LIQ  sector_Communication Services  \
# 0 -0.419834  0.345682  ...  1.959010                          False
# 1  1.665262  0.037950  ... -0.136873                          False
# 2 -0.355978 -0.254101  ... -0.788841                          False
# 3  0.002327 -0.071370  ... -0.007083                          False
# 4 -1.195322 -0.160618  ...  1.166198                          False
#
#    sector_Consumer Discretionary  sector_Consumer Staples  sector_Energy  \
# 0                          False                    False          False
# 1                          False                    False          False
# 2                          False                    False          False
# 3                          False                    False          False
# 4                          False                    False          False
#
#    sector_Financials  sector_Health Care  sector_Industrials  \
# 0              False               False               False
# 1              False                True               False
# 2              False                True               False
# 3              False               False               False
# 4              False               False               False
#
#    sector_Information Technology  sector_Materials
# 0                           True             False
# 1                          False             False
# 2                          False             False
# 3                           True             False
# 4                           True             False
#
# [5 rows x 26 columns]

# %%
factor_contrib, resid_contrib, total_model = decompose_portfolio_us(
    weights=weights_eq,
    factor_panel=factor_panel_with_sectors,  # enriched panel
    factor_returns=factor_returns,
    residuals=residuals,
)

# %%
true_ret, model_ret, diff, rmse, max_abs_diff = sanity_check_decomposition_us(
    weights=weights_eq,
    factor_panel=factor_panel,
    total_from_model=total_model,
)

# %%
rmse, max_abs_diff, pd.concat(
    [true_ret, model_ret, diff.rename("diff")], axis=1
).head()
# Out:
# (0.0014236578066900685,
#  0.00828486386478378,
#              portfolio_return_true  total_from_model      diff
#  date
#  2021-11-02               0.003650          0.003837 -0.000187
#  2021-11-03               0.007585          0.006681  0.000904
#  2021-11-04               0.010575          0.007705  0.002870
#  2021-11-05               0.000275          0.001768 -0.001493
#  2021-11-08               0.004338          0.002623  0.001715)

# %%
# Diagnostic

# %%
# Quick diagnostic in a scratch cell or notebook
import pandas as pd
from pathlib import Path

DATA_INT = Path(r"C:\Users\quantbase\Desktop\SyStrat_factmod\data_int")

mkt = pd.read_parquet(DATA_INT / "mkt_cap_all.parquet")
print("mkt_cap_all tickers:", mkt["ticker"].unique())
print(mkt.groupby("ticker")["mkt_cap"].apply(lambda s: s.notna().mean()))
# Out:
# mkt_cap_all tickers: ['AAPL' 'MSFT' 'RELIANCE' 'SBIN']
# ticker
# AAPL        1.0
# MSFT        1.0
# RELIANCE    0.0
# SBIN        0.0
# Name: mkt_cap, dtype: float64

# %%
import pandas as pd
from pathlib import Path

DATA_INT = Path(r"C:\Users\quantbase\Desktop\SyStrat_factmod\data_int")
px = pd.read_parquet(DATA_INT / "prices_us.parquet")
print(px["ticker"].unique())
print(px["ticker"].value_counts())
# Out:
# ['AAPL' 'AMZN' 'META' 'MSFT' 'NVDA']
# ticker
# AAPL    1232
# AMZN    1232
# META    1232
# MSFT    1232
# NVDA    1232
# Name: count, dtype: int64

# %%
import pandas as pd
from src.fm_config import DATA_INT

# 1) What’s in returns_all?
ret = pd.read_parquet(DATA_INT / "returns_all.parquet")
print("returns_all US tickers:", ret[ret["market"] == "US"]["ticker"].unique())
# Out:
# returns_all US tickers: ['AAPL' 'AMZN' 'META' 'MSFT' 'NVDA']

# %%
# 2) What’s in mkt_cap_all right now?
mkt = pd.read_parquet(DATA_INT / "mkt_cap_all.parquet")
print("mkt_cap_all tickers:", mkt["ticker"].unique())
print(
    mkt[mkt["market"] == "US"]
    .groupby("ticker")["mkt_cap"]
    .apply(lambda s: s.gt(0).mean())
)
# Out:
# mkt_cap_all tickers: ['AAPL' 'MSFT' 'RELIANCE' 'SBIN']
# ticker
# AAPL    1.0
# MSFT    1.0
# Name: mkt_cap, dtype: float64

# %%
import subprocess, sys
from pathlib import Path

PROJ_ROOT = Path(r"C:\Users\quantbase\Desktop\SyStrat_factmod")

def run_cli_module(mod_name: str):
    """
    Run `python -m <mod_name>` with the project root as cwd
    and print stdout/stderr.
    """
    print(f"\n=== Running: python -m {mod_name} ===")
    result = subprocess.run(
        [sys.executable, "-m", mod_name],
        cwd=PROJ_ROOT,
        text=True,
        capture_output=True,
    )
    print(result.stdout)
    if result.stderr:
        print("STDERR:\n", result.stderr)

# %%
run_cli_module("src.fm_data_prices")
run_cli_module("src.fm_fundamentals")
run_cli_module("src.fm_returns")
run_cli_module("src.fm_panel_us")
run_cli_module("src.fm_factors")
run_cli_module("src.fm_factor_panel")
run_cli_module("src.fm_factor_model_us")
run_cli_module("src.fm_decompose_us")
# Out:
# === Running: python -m src.fm_data_prices ===
# === US (SimFin) demo ===
# Dataset "us-shareprices-daily" on disk (1 days old).
# - Loading from disk ... Done!
# [US] Saved 140 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\prices_us.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\prices_us.csv
#   ticker       date  SimFinId  ...     volume  Dividend  shares_outstanding
# 0   AAPL 2019-12-19    111052  ...   98507788       NaN        1.777306e+10
# 1   AAPL 2019-12-20    111052  ...  276130972       NaN        1.777306e+10
# 2   AAPL 2019-12-23    111052  ...   98711532       NaN        1.777306e+10
# 3   AAPL 2019-12-24    111052  ...   48478856       NaN        1.777306e+10
# 4   AAPL 2019-12-26    111052  ...   93336016       NaN        1.777306e+10
#
# [5 rows x 11 columns]
#
# === NSE (jugaad-data) demo ===
# [NSE] Fetching SBIN from 2020-01-01 to 2020-03-31 (series=EQ)
# [NSE] Fetching RELIANCE from 2020-01-01 to 2020-03-31 (series=EQ)
# [NSE] Saved 155 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\prices_nse.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\prices_nse.csv
#      symbol       date    open  ...    volume         value  trades
# 0  RELIANCE 2020-01-01  1518.0  ...   6402372  9.701063e+09  122265
# 1  RELIANCE 2020-01-02  1512.0  ...   8096561  1.239471e+10  151727
# 2  RELIANCE 2020-01-03  1533.0  ...   9593498  1.470428e+10  149003
# 3  RELIANCE 2020-01-06  1520.0  ...  11209343  1.695494e+10  225138
# 4  RELIANCE 2020-01-07  1519.0  ...   7627191  1.161710e+10  180713
#
# [5 rows x 10 columns]
#
# STDERR:
#  C:\Users\quantbase\.conda\envs\factmod-311\Lib\site-packages\simfin\load.py:154: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv(path, sep=';', header=0,
#
#
# === Running: python -m src.fm_fundamentals ===
# === US fundamentals (SimFin) demo ===
# Dataset "us-income-ttm" on disk (1 days old).
# - Loading from disk ... Done!
# [US][income_ttm] Saved 40 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\us_income_ttm.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\us_income_ttm.csv
# [US] Income TTM head:
#   ticker report_date  ...   Net Income Net Income (Common)
# 0   AAPL  2019-12-31  ...  57527000000         57527000000
# 1   AAPL  2020-03-31  ...  57215000000         57215000000
# 2   AAPL  2020-06-30  ...  58424000000         58424000000
# 3   AAPL  2020-09-30  ...  57411000000         57411000000
# 4   AAPL  2020-12-31  ...  63930000000         63930000000
#
# [5 rows x 28 columns]
#
# Dataset "us-balance-ttm" on disk (1 days old).
# - Loading from disk ... Done!
# [US][balance_ttm] Saved 40 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\us_balance_ttm.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\us_balance_ttm.csv
# [US] Balance TTM head:
#   ticker report_date  ...  Total Equity Total Liabilities & Equity
# 0   AAPL  2019-12-31  ...  8.953100e+10               340618000000
# 1   AAPL  2020-03-31  ...  7.842500e+10               320400000000
# 2   AAPL  2020-06-30  ...  7.228200e+10               317344000000
# 3   AAPL  2020-09-30  ...  6.533900e+10               323888000000
# 4   AAPL  2020-12-31  ...  6.622400e+10               354054000000
#
# [5 rows x 30 columns]
#
# Dataset "us-cashflow-ttm" on disk (1 days old).
# - Loading from disk ... Done!
# [US][cashflow_ttm] Saved 40 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\us_cashflow_ttm.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\us_cashflow_ttm.csv
# [US] Cashflow TTM head:
#   ticker report_date  ...  Net Cash from Financing Activities Net Change in Cash
# 0   AAPL  2019-12-31  ...                       -1.027070e+11        -3106000000
# 1   AAPL  2020-03-31  ...                       -9.419000e+10         3232000000
# 2   AAPL  2020-06-30  ...                       -8.650200e+10       -17112000000
# 3   AAPL  2020-09-30  ...                       -8.682000e+10       -10435000000
# 4   AAPL  2020-12-31  ...                       -9.366200e+10        -3946000000
#
# [5 rows x 28 columns]
#
# [NSE] No fundamentals CSV found at data_raw/fundamentals_nse.csv; skipping NSE fundamentals demo.
#
# STDERR:
#  C:\Users\quantbase\.conda\envs\factmod-311\Lib\site-packages\simfin\load.py:154: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv(path, sep=';', header=0,
# C:\Users\quantbase\.conda\envs\factmod-311\Lib\site-packages\simfin\load.py:154: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv(path, sep=';', header=0,
# C:\Users\quantbase\.conda\envs\factmod-311\Lib\site-packages\simfin\load.py:154: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv(path, sep=';', header=0,
#
#
# === Running: python -m src.fm_returns ===
# === Building returns_all ===
# [RETURNS] Saved 291 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\returns_all.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\returns_all.csv
# === Building mkt_cap_all ===
# [MKT_CAP] Saved 295 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\mkt_cap_all.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\mkt_cap_all.csv
#
# [RETURNS] Sample slice:
#          date ticker market       ret
# 7  2020-01-02   AAPL     US  0.022885
# 8  2020-01-03   AAPL     US -0.009722
# 9  2020-01-06   AAPL     US  0.007934
# 10 2020-01-07   AAPL     US -0.004670
# 11 2020-01-08   AAPL     US  0.016086
#
# [MKT_CAP] Sample slice:
#          date ticker market       mkt_cap
# 8  2020-01-02   AAPL     US  1.317066e+12
# 9  2020-01-03   AAPL     US  1.304262e+12
# 10 2020-01-06   AAPL     US  1.314611e+12
# 11 2020-01-07   AAPL     US  1.308472e+12
# 12 2020-01-08   AAPL     US  1.329520e+12
#
# STDERR:
#  C:\Users\quantbase\Desktop\SyStrat_factmod\src\fm_returns.py:150: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all = pd.concat(frames, ignore_index=True)
#
#
# === Running: python -m src.fm_panel_us ===
# [US_PANEL] Saved 124 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\funds_panel_us.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\funds_panel_us.csv
#
# [US_PANEL] Sample slice (AAPL/MSFT, 2020-Q1):
#         date ticker market  ...  bal_report_date  cf_report_date inc_age_days
# 0 2020-01-02   AAPL     US  ...       2019-12-31      2019-12-31            2
# 1 2020-01-03   AAPL     US  ...       2019-12-31      2019-12-31            3
# 2 2020-01-06   AAPL     US  ...       2019-12-31      2019-12-31            6
# 3 2020-01-07   AAPL     US  ...       2019-12-31      2019-12-31            7
# 4 2020-01-08   AAPL     US  ...       2019-12-31      2019-12-31            8
#
# [5 rows x 9 columns]
#
#
# === Running: python -m src.fm_factors ===
# [STYLE_US_T1] Saved 124 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\style_us_tier1.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\style_us_tier1.csv
#
# [STYLE_US_T1] Sample slice (AAPL/MSFT, 2020-Q1):
#         date ticker market      SIZE       VAL  MOM
# 0 2020-01-02   AAPL     US  0.707107  0.707107  NaN
# 1 2020-01-03   AAPL     US  0.707107  0.707107  NaN
# 2 2020-01-06   AAPL     US  0.707107  0.707107  NaN
# 3 2020-01-07   AAPL     US  0.707107  0.707107  NaN
# 4 2020-01-08   AAPL     US  0.707107  0.707107  NaN
# [STYLE_US_T2] Saved 124 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\style_us_tier2.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\style_us_tier2.csv
#
# [STYLE_US_T2] Sample slice (AAPL/MSFT, 2020-Q1):
#         date ticker market      QUAL  ...      GM_z  CashEY_z   LEV_raw     LEV_z
# 0 2020-01-02   AAPL     US  0.707107  ... -0.707107  0.707107  0.737151  0.707107
# 1 2020-01-03   AAPL     US  0.707107  ... -0.707107  0.707107  0.737151  0.707107
# 2 2020-01-06   AAPL     US  0.707107  ... -0.707107  0.707107  0.737151  0.707107
# 3 2020-01-07   AAPL     US  0.707107  ... -0.707107  0.707107  0.737151  0.707107
# 4 2020-01-08   AAPL     US  0.707107  ... -0.707107  0.707107  0.737151  0.707107
#
# [5 rows x 9 columns]
# [STYLE_US_T3] Saved 124 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\style_us_tier3.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\style_us_tier3.csv
#
# [STYLE_US_T3] Sample slice (AAPL/MSFT, 2020-Q1):
#         date ticker market  EMA20_GAP  VOL_Z       LIQ
# 0 2020-01-02   AAPL     US        NaN    NaN  0.707107
# 1 2020-01-03   AAPL     US   0.707107    NaN  0.707107
# 2 2020-01-06   AAPL     US   0.707107    NaN  0.707107
# 3 2020-01-07   AAPL     US   0.707107    NaN  0.707107
# 4 2020-01-08   AAPL     US   0.707107    NaN  0.707107
# [STYLE_US_FULL] Saved 124 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\style_us_full.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\style_us_full.csv
#
# [STYLE_US_FULL] Sample slice (AAPL/MSFT, 2020-Q1):
#         date ticker market      SIZE  ...     LEV_z  EMA20_GAP  VOL_Z       LIQ
# 0 2020-01-02   AAPL     US  0.707107  ...  0.707107        NaN    NaN  0.707107
# 1 2020-01-03   AAPL     US  0.707107  ...  0.707107   0.707107    NaN  0.707107
# 2 2020-01-06   AAPL     US  0.707107  ...  0.707107   0.707107    NaN  0.707107
# 3 2020-01-07   AAPL     US  0.707107  ...  0.707107   0.707107    NaN  0.707107
# 4 2020-01-08   AAPL     US  0.707107  ...  0.707107   0.707107    NaN  0.707107
#
# [5 rows x 15 columns]
#
#
# === Running: python -m src.fm_factor_panel ===
# [FACTOR_PANEL_US] Saved 124 rows to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_panel_us.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_panel_us.csv
#
# [FACTOR_PANEL_US] Sample slice (AAPL/MSFT, 2020-Q1):
#         date ticker market       ret  ...      QUAL  EMA20_GAP  VOL_Z       LIQ
# 0 2020-01-02   AAPL     US  0.022885  ...  0.707107        NaN    NaN  0.707107
# 1 2020-01-02   MSFT     US  0.018516  ... -0.707107        NaN    NaN -0.707107
# 2 2020-01-03   AAPL     US -0.009722  ...  0.707107   0.707107    NaN  0.707107
# 3 2020-01-03   MSFT     US -0.012452  ... -0.707107  -0.707107    NaN -0.707107
# 4 2020-01-06   AAPL     US  0.007934  ...  0.707107   0.707107    NaN  0.707107
#
# [5 rows x 12 columns]
#
#
# === Running: python -m src.fm_factor_model_us ===
# [TORANIKO_INPUTS_US] Using 86 rows with complete style data and 7 style factors: ['SIZE', 'VAL', 'MOM', 'QUAL', 'EMA20_GAP', 'VOL_Z', 'LIQ']
# [FACTOR_MODEL_US] Saved factor returns (43 rows) to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_returns_us.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_returns_us.csv
# [FACTOR_MODEL_US] Saved residuals (43 rows) to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_residuals_us.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_residuals_us.csv
# [FACTOR_MODEL_US] Saved factor covariance matrix to C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_cov_us.parquet and C:\Users\quantbase\Desktop\SyStrat_factmod\data_int\factor_cov_us.csv
#
# [FACTOR_MODEL_US] Factor returns (head):
#               market  sector_all  EMA20_GAP  ...      SIZE       VAL     VOL_Z
# date                                         ...
# 2020-01-30  0.013202         0.0   0.002338  ... -0.002338 -0.002338 -0.002338
# 2020-01-31 -0.029681         0.0   0.002457  ... -0.002457 -0.002457 -0.002457
# 2020-02-03  0.010783         0.0   0.002179  ... -0.002179 -0.002179 -0.002179
# 2020-02-04  0.032915         0.0  -0.000030  ...  0.000030  0.000030  0.000030
# 2020-02-05  0.003492         0.0  -0.000763  ...  0.000763  0.000763  0.000763
#
# [5 rows x 9 columns]
#
# [FACTOR_MODEL_US] Residuals (head):
#                     AAPL      MSFT
# date
# 2020-01-30 -3.016218e-05  0.000476
# 2020-01-31  4.649300e-04 -0.000199
# 2020-02-03  2.092288e-08  0.000098
# 2020-02-04 -1.492563e-04  0.000149
# 2020-02-05 -4.958409e-05 -0.000002
#
# [FACTOR_MODEL_US] Factor covariance (annualised):
#               market  sector_all  EMA20_GAP  ...      SIZE       VAL     VOL_Z
# market      0.628394         0.0   0.002195  ... -0.000887 -0.003247  0.006696
# sector_all  0.000000         0.0   0.000000  ...  0.000000  0.000000  0.000000
# EMA20_GAP   0.002195         0.0   0.000484  ...  0.000185 -0.000414  0.000015
# LIQ        -0.003247         0.0  -0.000414  ... -0.000101  0.000524  0.000030
# MOM        -0.002878         0.0   0.000029  ...  0.000196 -0.000056 -0.000105
# QUAL       -0.003247         0.0  -0.000414  ... -0.000101  0.000524  0.000030
# SIZE       -0.000887         0.0   0.000185  ...  0.000549 -0.000101  0.000252
# VAL        -0.003247         0.0  -0.000414  ... -0.000101  0.000524  0.000030
# VOL_Z       0.006696         0.0   0.000015  ...  0.000252  0.000030  0.000553
#
# [9 rows x 9 columns]
#
#
# === Running: python -m src.fm_decompose_us ===
#
# [DECOMPOSE_US] Factor contributions (head):
#               market  sector_all     EMA20_GAP  ...          SIZE  VAL         VOL_Z
# date                                            ...
# 2020-01-30  0.013202         0.0  0.000000e+00  ...  7.787147e-17 -0.0 -1.427644e-18
# 2020-01-31 -0.029681         0.0  0.000000e+00  ... -1.373679e-16 -0.0 -0.000000e+00
# 2020-02-03  0.010783         0.0  0.000000e+00  ...  3.017394e-16 -0.0 -0.000000e+00
# 2020-02-04  0.032915         0.0 -0.000000e+00  ...  0.000000e+00  0.0 -8.318734e-21
# 2020-02-05  0.003492         0.0 -4.232750e-20  ... -6.971339e-17  0.0  0.000000e+00
#
# [5 rows x 9 columns]
#
# [DECOMPOSE_US] Idiosyncratic contributions (head):
# date
# 2020-01-30    2.229667e-04
# 2020-01-31    1.329358e-04
# 2020-02-03    4.914833e-05
# 2020-02-04    4.124589e-09
# 2020-02-05   -2.576700e-05
# Name: idiosyncratic, dtype: float64
#
# [DECOMPOSE_US] Total portfolio return from model (head):
# date
# 2020-01-30    0.013425
# 2020-01-31   -0.029548
# 2020-02-03    0.010832
# 2020-02-04    0.032915
# 2020-02-05    0.003467
# Name: total_from_model, dtype: float64
# [DECOMPOSE_US] Saved decomposition artifacts
#
# [DECOMPOSE_US] Sanity check vs realised portfolio returns:
#   Common dates: 43
#   Max abs diff: 3.469e-18
#   RMSE diff   : 1.016e-18
#
# [DECOMPOSE_US] True vs model (head):
#             portfolio_return_true  total_from_model          diff
# date
# 2020-01-30               0.013425          0.013425  0.000000e+00
# 2020-01-31              -0.029548         -0.029548  3.469447e-18
# 2020-02-03               0.010832          0.010832  0.000000e+00
# 2020-02-04               0.032915          0.032915  0.000000e+00
# 2020-02-05               0.003467          0.003467  0.000000e+00

# %%
panel_us = pd.read_parquet(DATA_INT / "funds_panel_us.parquet")

panel_us[panel_us["inc_report_date"].notna()].head()
# Out:
#          date ticker market       ret       mkt_cap inc_report_date  \
# 6  2019-12-31   AAPL     US  0.007272  1.287599e+12      2019-12-31
# 7  2020-01-02   AAPL     US  0.022885  1.317066e+12      2019-12-31
# 8  2020-01-03   AAPL     US -0.009722  1.304262e+12      2019-12-31
# 9  2020-01-06   AAPL     US  0.007934  1.314611e+12      2019-12-31
# 10 2020-01-07   AAPL     US -0.004670  1.308472e+12      2019-12-31
#
#     inc_SimFinId inc_Currency  inc_Fiscal Year inc_Fiscal Period  ...  \
# 6       111052.0          USD           2020.0                Q1  ...
# 7       111052.0          USD           2020.0                Q1  ...
# 8       111052.0          USD           2020.0                Q1  ...
# 9       111052.0          USD           2020.0                Q1  ...
# 10      111052.0          USD           2020.0                Q1  ...
#
#    cf_Change in Fixed Assets & Intangibles  \
# 6                            -9.247000e+09
# 7                            -9.247000e+09
# 8                            -9.247000e+09
# 9                            -9.247000e+09
# 10                           -9.247000e+09
#
#    cf_Net Change in Long Term Investment  \
# 6                           3.827500e+10
# 7                           3.827500e+10
# 8                           3.827500e+10
# 9                           3.827500e+10
# 10                          3.827500e+10
#
#     cf_Net Cash from Acquisitions & Divestitures  \
# 6                                  -1.415000e+09
# 7                                  -1.415000e+09
# 8                                  -1.415000e+09
# 9                                  -1.415000e+09
# 10                                 -1.415000e+09
#
#     cf_Net Cash from Investing Activities  cf_Dividends Paid  \
# 6                            2.638400e+10      -1.409000e+10
# 7                            2.638400e+10      -1.409000e+10
# 8                            2.638400e+10      -1.409000e+10
# 9                            2.638400e+10      -1.409000e+10
# 10                           2.638400e+10      -1.409000e+10
#
#     cf_Cash from (Repayment of) Debt  cf_Cash from (Repurchase of) Equity  \
# 6                      -7.594000e+09                        -7.802400e+10
# 7                      -7.594000e+09                        -7.802400e+10
# 8                      -7.594000e+09                        -7.802400e+10
# 9                      -7.594000e+09                        -7.802400e+10
# 10                     -7.594000e+09                        -7.802400e+10
#
#     cf_Net Cash from Financing Activities  cf_Net Change in Cash  inc_age_days
# 6                           -1.027070e+11          -3.106000e+09           0.0
# 7                           -1.027070e+11          -3.106000e+09           2.0
# 8                           -1.027070e+11          -3.106000e+09           3.0
# 9                           -1.027070e+11          -3.106000e+09           6.0
# 10                          -1.027070e+11          -3.106000e+09           7.0
#
# [5 rows x 89 columns]
